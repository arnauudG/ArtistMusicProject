# %%
import os
from datetime import datetime
import json
import lyricsgenius as lg
import pandas as pd

# %%
artist_name = "Zamdane"

# %%
genius = lg.Genius(access_token=os.environ['GENIUS_CLIENT_ACCESS_TOKEN'],
                   excluded_terms=["(Remix)", "(Live)", "(Freestyle)", "(Instrumental)"],
                   retries=10,
                   timeout=60)

genius_search_artist_result_dict = genius.search_artist(artist_name,
                                                        max_songs=999,
                                                        get_full_info=True,
                                                        allow_name_change=False).to_dict()
# Out:
# Searching for songs by Zamdane...
#
# Song 1: "Favaro"
# Song 2: "Affamé #8 - Hayati"
# Song 3: "Boyka"
# Song 4: "Disaster"
# "Noir (Remix)" is not valid. Skipping.
# Song 5: "Le monde par ma fenêtre"
# "Règlement Freestyle #6" is not valid. Skipping.
# Song 6: "Vide quand t’es pas là"
# Song 7: "Affamé #16 - Triste mais elle aime ça"
# Song 8: "Mouchkila"
# Song 9: "Quand j’fume"
# Song 10: "1,2,3,4"
# Song 11: "Flouka"
# "Freestyle #11RappeursASuivre2022" is not valid. Skipping.
# Song 12: "Affamé #1 - Shook"
# Song 13: "Tout ce qu’il voulait"
# Song 14: "Zhar"
# Song 15: "Stradivarius"
# Song 16: "Minato"
# Song 17: "Affamé #10 - Athéna"
# Song 18: "Naïf"
# Song 19: "TJPC"
# Song 20: "Deadstar"
# Song 21: "Affamé #2 - 21"
# Song 22: "Fauves"
# Song 23: "Fallait"
# Song 24: "Million"
# Song 25: "Alouette"
# Song 26: "Youm wara youm"
# Song 27: "Noum"
# Song 28: "Foust L’Bando"
# Song 29: "Monstres"
# Song 30: "Doko"
# Song 31: "Nil"
# Song 32: "Fleurs"
# Song 33: "Affamé #12 - Sentimental"
# Song 34: "Affamé #13 - Marseille"
# Song 35: "Padmé"
# Song 36: "Green"
# Song 37: "Affamé #11 - Photogénique (Boosk’Affamé)"
# Song 38: "Incomplet comme février"
# Song 39: "Sinbad"
# Song 40: "Bonne année"
# Song 41: "Mélancolie criminelle"
# Song 42: "Affamé #17 - Angels"
# Song 43: "Affamé #14 - Poussière"
# Song 44: "Synchtene"
# Song 45: "Affamé #4 - Survivant"
# Song 46: "Affamé #15 - Conditionnés à décevoir"
# Song 47: "Printemps"
# Song 48: "C18"
# Song 49: "Oh Mama"
# Song 50: "Le grand cirque"
# Song 51: "Lettre à mon dieu"
# Song 52: "Affamé #7 - Histoires de la vraie vie"
# Song 53: "Loin d’ici"
# Song 54: "Libre comme une colombe"
# Song 55: "Affamé #5 - Seul"
# Song 56: "Affamé #3 - No Party"
# Song 57: "Affamé #6 - Vital"
# Song 58: "Même à distance on est proches"
# Song 59: "Lalalala"
# Song 60: "Cream"
# Song 61: "Pour mourir"
# Song 62: "Groupie love"
# Song 63: "Boboalam"
# Song 64: "À ma guise"
# Song 65: "Étoiles dans les yeux"
# Song 66: "Affamé #19 - Ma réalité"
# Song 67: "Affamé #9 - GRRR"
# Song 68: "Classe S"
# Song 69: "Demain"
# Song 70: "Bulle"
# Song 71: "Formidable (Affamé #21)"
# Song 72: "Dans l’mal"
# Song 73: "Azura"
# Song 74: "Affamé #18 - Bataille"
# Song 75: "Un peu de moi"
# Song 76: "Passe à l’appart"
# Song 77: "Audi GT"
# Song 78: "7"
# Song 79: "NTM"
# Song 80: "MOB (Affamé #20)"
# Song 81: "Infini"
# Song 82: "Mektoub"
# Song 83: "Zéro"
# Song 84: "Une éternité ne suffit pas (Affamé #22)"
# Song 85: "Rolling Up"
# Song 86: "Si on s’aimait"
# "Freestyle 13 organisé 2" is not valid. Skipping.
# Song 87: "Stylo magique"
# Song 88: "Médusa"
# Song 89: "Low"
# Song 90: "Ronaldinho"
# Song 91: "Mémoire"
# Song 92: "Ça y est, ça y est"
# Song 93: "Paradis"
# Song 94: "Dans le noir"
# Song 95: "Recommence"
# Song 96: "Next Up France - S1-E1"
# Song 97: "PP"
# Song 98: "Cage dorée"
# Song 99: "5h37*"
# Song 100: "Sablier"
# Song 101: "La fête"
# Song 102: "Favélas"
# Song 103: "Potentiel"
# "FREESTYLE JEU$" is not valid. Skipping.
# Song 104: "TAGGLE"
# "Freestyle Couvre Feu" is not valid. Skipping.
# Song 105: "Salopard"
# Song 106: "Bitch’s Love"
# Song 107: "Une dernière fois*"
# "Freestyle Z #2" is not valid. Skipping.
# Song 108: "Chanel"
# Song 109: "HomyRecords #2"
# "Freestyle  Z #1" is not valid. Skipping.
# Song 110: "L.A*"
# Song 111: "Passage dans saison 3 épisode 3*"
# "Grünt d’Or #2" is not valid. Skipping.
# "En corps en cœur*" is not valid. Skipping.
# "From Time (Freestyle France Inter)" is not valid. Skipping.
# Song 112: "Ken le survivant*"
# "P. Diddy (Instrumental)" is not valid. Skipping.
# Done. Found 112 songs.

# %%
from typing import Dict, Any

# Define a constant for unknown values
UNKNOWN_VALUE = 'UNKNOWN'

def extract_value(data: Dict[str, Any], key_path: list, UNKNOWN_VALUE=UNKNOWN_VALUE) -> Any:
    """
    Extracts a value from a nested dictionary based on the provided list of keys (key_path).
    
    This function traverses the dictionary `data` using the keys in `key_path`. If any key along the path is not 
    present or the value is not found, it returns the `UNKNOWN_VALUE` constant. It also handles cases where a 
    non-dictionary value is encountered in the middle of the path.
    
    Args:
        data (Dict[str, Any]): The dictionary from which the value will be extracted.
        key_path (list): A list of keys representing the path to the target value.
        UNKNOWN_VALUE (str): The value to return if any key in the path is missing. Defaults to 'UNKNOWN'.
    
    Returns:
        Any: The value found at the specified key path, or 'UNKNOWN' if not found.
    """
    
    value = data

    try:
        for key in key_path:
            value = value.get(key, UNKNOWN_VALUE)
            if value == UNKNOWN_VALUE:
                break
    except AttributeError:
        return UNKNOWN_VALUE
    
    return value if value else UNKNOWN_VALUE

# %%
from typing import Dict, Any

def build_artist_song_genius(raw_data_artist_song_dict: Dict[str, Any], UNKNOWN_VALUE: Any = 'UNKNOWN') -> Dict[str, Any]:
    """
    Extracts and structures song information from the raw data retrieved from Genius.

    This function processes a nested dictionary (`raw_data_artist_song_dict`) representing song information 
    from Genius and returns a dictionary containing relevant details like song ID, title, release date, 
    album information, pageviews, and artist information. If any key is missing, it defaults to `UNKNOWN_VALUE`.

    Args:
        raw_data_artist_song_dict (Dict[str, Any]): Raw data dictionary containing song information.
        UNKNOWN_VALUE (Any): The value to return when required data is missing. Defaults to 'UNKNOWN'.

    Returns:
        Dict[str, Any]: A dictionary containing extracted song details such as title, album info, artist info, and more.
    """

    def safe_get(data: Dict[str, Any], key: str, default: Any = UNKNOWN_VALUE) -> Any:
        """Safely extract a value from a dictionary."""
        return data.get(key, default)

    def safe_extract(key_path: list) -> Any:
        """Helper function to safely extract nested values using extract_value."""
        return extract_value(raw_data_artist_song_dict, key_path, UNKNOWN_VALUE)

    # Dictionary to store song information
    artist_song_data = {
        'genius_song_id': safe_get(raw_data_artist_song_dict, 'id'),
        'full_title': safe_get(raw_data_artist_song_dict, 'full_title'),
        'release_date': safe_get(raw_data_artist_song_dict, 'release_date'),
        'genius_album_id': safe_extract(['album', 'id']),
        'album_name': safe_extract(['album', 'name']),
        'genius_album_api_path': safe_extract(['album', 'api_path']),
        'genius_song_api_path': safe_get(raw_data_artist_song_dict, 'api_path'),
        'pageviews_genius': safe_extract(['stats', 'pageviews']),
        'genius_song_url': safe_get(raw_data_artist_song_dict, 'url'),
        'genius_song_image_url': safe_get(raw_data_artist_song_dict, 'song_art_image_url'),
        'language': safe_get(raw_data_artist_song_dict, 'language'),
        'genius_song_description': safe_extract(["description", "plain"]),
        'lyrics': safe_get(raw_data_artist_song_dict, 'lyrics'),
        'lyrics_is_complete': safe_get(raw_data_artist_song_dict, 'lyrics_state'),
    }

    # Extract primary artist's name safely
    primary_artist = safe_get(raw_data_artist_song_dict.get('primary_artist', {}), 'name', UNKNOWN_VALUE)
    artist_song_data['primary_artist'] = primary_artist

    # Extract other primary artists excluding the main primary artist
    primary_artists = safe_get(raw_data_artist_song_dict, 'primary_artists', [])
    artist_song_data['primary_artists'] = [
        artist.get('name', UNKNOWN_VALUE) for artist in primary_artists 
        if artist.get('name') != primary_artist
    ]

    # Extract featured artists
    artist_song_data['featured_artists'] = safe_get(raw_data_artist_song_dict, 'featured_artists', UNKNOWN_VALUE)

    return artist_song_data

# %%
def build_artist_info_genius(search_artist_result_dict: Dict[str, Any], UNKNOWN_VALUE: Any = "UNKNOWN") -> Dict[str, Any]:
    """
    Extracts and builds a dictionary containing artist information from the Genius API search result.

    Parameters:
    - search_artist_result_dict (Dict[str, Any]): The dictionary containing the search result from the Genius API.
    - UNKNOWN_VALUE (Any): The default value to use for missing keys. Defaults to "UNKNOWN".

    Returns:
    - Dict[str, Any]: A dictionary containing the extracted artist information.
    """
    artist_info = {
        'genius_artist_id': search_artist_result_dict.get('id', UNKNOWN_VALUE),
        'artist_name': search_artist_result_dict.get('name', UNKNOWN_VALUE),
        'genius_artist_api_path': search_artist_result_dict.get('api_path', UNKNOWN_VALUE),
        'genius_artist_url': search_artist_result_dict.get('url', UNKNOWN_VALUE),
        'genius_artist_image_url': search_artist_result_dict.get('image_url', UNKNOWN_VALUE),
        'genius_artist_description': extract_value(search_artist_result_dict, ["description", "plain"], UNKNOWN_VALUE),
        'twitter_name': search_artist_result_dict.get('twitter_name', UNKNOWN_VALUE),
        'facebook_name': search_artist_result_dict.get('facebook_name', UNKNOWN_VALUE),
        'instagram_name': search_artist_result_dict.get('instagram_name', UNKNOWN_VALUE),
        'is_verified_genius': search_artist_result_dict.get('is_verified', UNKNOWN_VALUE),
        'tracks': [build_artist_song_genius(song) for song in search_artist_result_dict.get('songs', [])]
    }

    return artist_info

# %%
artist_data = build_artist_info_genius(genius_search_artist_result_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 artist_data = build_artist_info_genius(genius_search_artist_result_dict)
#
# NameError: name 'genius_search_artist_result_dict' is not defined

# %%
with open(f"./assets/{artist_name}-{datetime.today().date()}-Genius.json", 'w') as f_in:
    json.dump(artist_data, f_in, indent=4)

# %%
with open(f"./assets/{artist_name}-{datetime.today().date()}-Genius.json", 'r') as f_out:
    artist = json.load(f_out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with open(f"./assets/{artist_name}-{datetime.today().date()}-Genius.json", 'r') as f_out:
#       2     artist = json.load(f_out)
#
# File ~/Learning/projects/Artist-Data/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './assets/Zamdane-2024-10-18-Genius.json'

# %%
for track_num, track in enumerate(artist['tracks']):
    print(f"Track {track_num} - {track['full_title']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for track_num, track in enumerate(artist['tracks']):
#       2     print(f"Track {track_num} - {track['full_title']}")
#
# NameError: name 'artist' is not defined

# %%
dataset = pd.DataFrame(artist)

# %%
dataset.head(n = 10)
# Out:
#    genius_artist_id artist_name genius_artist_api_path  \
# 0           1159944     Zamdane       /artists/1159944
# 1           1159944     Zamdane       /artists/1159944
# 2           1159944     Zamdane       /artists/1159944
# 3           1159944     Zamdane       /artists/1159944
# 4           1159944     Zamdane       /artists/1159944
# 5           1159944     Zamdane       /artists/1159944
# 6           1159944     Zamdane       /artists/1159944
# 7           1159944     Zamdane       /artists/1159944
# 8           1159944     Zamdane       /artists/1159944
# 9           1159944     Zamdane       /artists/1159944
#
#                     genius_artist_url  \
# 0  https://genius.com/artists/Zamdane
# 1  https://genius.com/artists/Zamdane
# 2  https://genius.com/artists/Zamdane
# 3  https://genius.com/artists/Zamdane
# 4  https://genius.com/artists/Zamdane
# 5  https://genius.com/artists/Zamdane
# 6  https://genius.com/artists/Zamdane
# 7  https://genius.com/artists/Zamdane
# 8  https://genius.com/artists/Zamdane
# 9  https://genius.com/artists/Zamdane
#
#                              genius_artist_image_url  \
# 0  https://images.genius.com/2db9ead74b2f66a18bda...
# 1  https://images.genius.com/2db9ead74b2f66a18bda...
# 2  https://images.genius.com/2db9ead74b2f66a18bda...
# 3  https://images.genius.com/2db9ead74b2f66a18bda...
# 4  https://images.genius.com/2db9ead74b2f66a18bda...
# 5  https://images.genius.com/2db9ead74b2f66a18bda...
# 6  https://images.genius.com/2db9ead74b2f66a18bda...
# 7  https://images.genius.com/2db9ead74b2f66a18bda...
# 8  https://images.genius.com/2db9ead74b2f66a18bda...
# 9  https://images.genius.com/2db9ead74b2f66a18bda...
#
#                            genius_artist_description twitter_name  \
# 0  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 1  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 2  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 3  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 4  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 5  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 6  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 7  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 8  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
# 9  Zamdane, de son vrai nom Ayoub Zaidane, est un...      zamdane
#
#   facebook_name instagram_name  is_verified_genius  \
# 0       zvmdvne        zamdane                True
# 1       zvmdvne        zamdane                True
# 2       zvmdvne        zamdane                True
# 3       zvmdvne        zamdane                True
# 4       zvmdvne        zamdane                True
# 5       zvmdvne        zamdane                True
# 6       zvmdvne        zamdane                True
# 7       zvmdvne        zamdane                True
# 8       zvmdvne        zamdane                True
# 9       zvmdvne        zamdane                True
#
#                                               tracks
# 0  {'genius_song_id': 3128292, 'full_title': 'Fav...
# 1  {'genius_song_id': 6541840, 'full_title': 'Aff...
# 2  {'genius_song_id': 7135091, 'full_title': 'Boy...
# 3  {'genius_song_id': 3611055, 'full_title': 'Dis...
# 4  {'genius_song_id': 6893603, 'full_title': 'Le ...
# 5  {'genius_song_id': 3313568, 'full_title': 'Règ...
# 6  {'genius_song_id': 7640457, 'full_title': 'Vid...
# 7  {'genius_song_id': 8891158, 'full_title': 'Aff...
# 8  {'genius_song_id': 10084479, 'full_title': 'Mo...
# 9  {'genius_song_id': 3611076, 'full_title': 'Qua...

# %%
pd.DataFrame(list(dataset['tracks'].values))
# Out:
#      genius_song_id                                         full_title  \
# 0           3128292                                  Favaro by Zamdane
# 1           6541840                      Affamé #8 - Hayati by Zamdane
# 2           7135091                       Boyka by Zamdane (Ft. Dinos)
# 3           3611055                                Disaster by Zamdane
# 4           6893603                 Le monde par ma fenêtre by Zamdane
# ..              ...                                                ...
# 112         4566479                         Freestyle  Z #1 by Zamdane
# 113         5634312                                    L.A* by Zamdane
# 114         8368731  Passage dans saison 3 épisode 3* by Zamdane (F...
# 115        10286853      From Time (Freestyle France Inter) by Zamdane
# 116        10870217                       Ken le survivant* by Zamdane
#
#     release_date genius_album_id           album_name genius_album_api_path  \
# 0     2017-06-08          425938     Nova Grünt Tunes        /albums/425938
# 1     2021-03-03          728748    Affamé - Saison 2        /albums/728748
# 2     2021-12-08          864511  Couleur de ma peine        /albums/864511
# 3     2018-03-28          414601                 20's        /albums/414601
# 4     2022-01-26          864511  Couleur de ma peine        /albums/864511
# ..           ...             ...                  ...                   ...
# 112   2019-05-17         UNKNOWN              UNKNOWN               UNKNOWN
# 113         None         UNKNOWN              UNKNOWN               UNKNOWN
# 114         None         UNKNOWN              UNKNOWN               UNKNOWN
# 115   2024-04-15         UNKNOWN              UNKNOWN               UNKNOWN
# 116         None         UNKNOWN              UNKNOWN               UNKNOWN
#
#     genius_song_api_path pageviews_genius  \
# 0         /songs/3128292            47099
# 1         /songs/6541840            21299
# 2         /songs/7135091            19777
# 3         /songs/3611055            17585
# 4         /songs/6893603            13511
# ..                   ...              ...
# 112       /songs/4566479          UNKNOWN
# 113       /songs/5634312          UNKNOWN
# 114       /songs/8368731          UNKNOWN
# 115      /songs/10286853          UNKNOWN
# 116      /songs/10870217          UNKNOWN
#
#                                        genius_song_url  \
# 0             https://genius.com/Zamdane-favaro-lyrics
# 1    https://genius.com/Zamdane-affame-8-hayati-lyrics
# 2              https://genius.com/Zamdane-boyka-lyrics
# 3           https://genius.com/Zamdane-disaster-lyrics
# 4    https://genius.com/Zamdane-le-monde-par-ma-fen...
# ..                                                 ...
# 112    https://genius.com/Zamdane-freestyle-z-1-lyrics
# 113               https://genius.com/Zamdane-la-lyrics
# 114  https://genius.com/Zamdane-passage-dans-saison...
# 115  https://genius.com/Zamdane-from-time-freestyle...
# 116  https://genius.com/Zamdane-ken-le-survivant-ly...
#
#                                  genius_song_image_url language  \
# 0    https://images.genius.com/a6f7c834c0f61121da8a...       fr
# 1    https://images.genius.com/73daff9eae6de9695697...       fr
# 2    https://images.genius.com/e494e1e555a57242f4ed...       fr
# 3    https://images.genius.com/b58f66f07ca79d120df5...       fr
# 4    https://images.genius.com/d12628ac45c453238291...       fr
# ..                                                 ...      ...
# 112  https://images.genius.com/2db9ead74b2f66a18bda...       fr
# 113  https://images.genius.com/2db9ead74b2f66a18bda...       fr
# 114  https://images.genius.com/2db9ead74b2f66a18bda...       fr
# 115  https://images.genius.com/2db9ead74b2f66a18bda...       fr
# 116  https://images.genius.com/2db9ead74b2f66a18bda...       fr
#
#                                genius_song_description  \
# 0    Second morceau de l'artiste marseillais Zamdan...
# 1                                                    ?
# 2                                                    ?
# 3    Premier extrait de “ 20’s ”, le premier EP de ...
# 4                                                    ?
# ..                                                 ...
# 112                                                  ?
# 113                                                  ?
# 114                                                  ?
# 115                                                  ?
# 116  Exclu teasé le 11 septembre 2024 et disponible...
#
#                                                 lyrics lyrics_is_complete  \
# 0    36 ContributorsFavaro Lyrics[Paroles de "Favar...           complete
# 1    18 ContributorsAffamé #8 - Hayati Lyrics[Parol...           complete
# 2    32 ContributorsBoyka Lyrics[Paroles de "Boyka"...           complete
# 3    13 ContributorsDisaster Lyrics[Paroles de "Dis...           complete
# 4    13 ContributorsLe monde par ma fenêtre Lyrics[...           complete
# ..                                                 ...                ...
# 112  3 ContributorsFreestyle  Z #1 Lyrics[Couplet u...           complete
# 113  2 ContributorsL.A* LyricsCouplet 1 :\n\nJ'ai p...           complete
# 114  2 ContributorsPassage dans saison 3 épisode 3*...           complete
# 115  1 ContributorFrom Time (Freestyle France Inter...           complete
# 116  1 ContributorKen le survivant* Lyrics[Couplet ...           complete
#
#     primary_artist primary_artists  \
# 0          Zamdane              []
# 1          Zamdane              []
# 2          Zamdane              []
# 3          Zamdane              []
# 4          Zamdane              []
# ..             ...             ...
# 112        Zamdane              []
# 113        Zamdane              []
# 114        Zamdane              []
# 115        Zamdane              []
# 116        Zamdane              []
#
#                                       featured_artists
# 0                                                   []
# 1                                                   []
# 2    [{'api_path': '/artists/14806', 'header_image_...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 112                                                 []
# 113                                                 []
# 114  [{'api_path': '/artists/12085', 'header_image_...
# 115                                                 []
# 116                                                 []
#
# [117 rows x 17 columns]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set up client credentials
client_credentials_manager = SpotifyClientCredentials(os.environ['CLIENT_ID_SPOTIFY'], os.environ['CLIENT_SECRET_SPOTIFY'])
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
spotify_artist_search_result_dict = sp.search(artist_name, type='artist')

# %%
spotify_artist_data = {}

spotify_raw_data_artist_dict = extract_value(spotify_artist_search_result_dict,
                                             ['artists', 'items'],
                                             UNKNOWN_VALUE)[0]

# %%
def build_artist_info_spotify(spotify_raw_data_artist_dict: Dict[str, Any], UNKNOWN_VALUE: Any = "UNKNOWN") -> Dict[str, Any]:
    """
    Extracts and builds a dictionary containing artist information from the Spotipy API search result.

    Parameters:
    - spotify_raw_data_artist_dict (Dict[str, Any]): The dictionary containing the search result from the Spotipy
    - UNKNOWN_VALUE (Any): The default value to use for missing keys. Defaults to "UNKNOWN".

    Returns:
    - Dict[str, Any]: A dictionary containing the extracted artist information.
    """
    artist_info = {
        'artist_name': spotify_raw_data_artist_dict.get('name', UNKNOWN_VALUE),
        'artist_id_spotify': spotify_raw_data_artist_dict.get('id', UNKNOWN_VALUE),
        'artist_uri_spotify': spotify_raw_data_artist_dict.get('uri', UNKNOWN_VALUE),
        'artist_link_picture_spotify': extract_value(spotify_raw_data_artist_dict, ['images', 'url'], UNKNOWN_VALUE),
        'artist_genres_spotify': spotify_raw_data_artist_dict.get('genres', UNKNOWN_VALUE),
        'artist_popularity_spotify': spotify_raw_data_artist_dict.get('popularity', UNKNOWN_VALUE),
        'artist_related_artists_spotify': [related_artist_name['name'] for related_artist_name in sp.artist_related_artists(spotify_raw_data_artist_dict.get('id', UNKNOWN_VALUE)).get('artists', UNKNOWN_VALUE)],
        'artist_tracks': []
    }

    return artist_info

# %%
spotify_raw_data_artist_dict
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CtPAGoxpJ4yLJLx6CSrO8'},
#  'followers': {'href': None, 'total': 195082},
#  'genres': ['cloud rap francais',
#   'french hip hop',
#   'pop urbaine',
#   'rap conscient',
#   'rap francais'],
#  'href': 'https://api.spotify.com/v1/artists/5CtPAGoxpJ4yLJLx6CSrO8',
#  'id': '5CtPAGoxpJ4yLJLx6CSrO8',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebc99fc3269d0996195e2308d6',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174c99fc3269d0996195e2308d6',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178c99fc3269d0996195e2308d6',
#    'width': 160}],
#  'name': 'Zamdane',
#  'popularity': 60,
#  'type': 'artist',
#  'uri': 'spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8'}

# %%
spotify_artist_info = build_artist_info_spotify(spotify_raw_data_artist_dict)

# %%
spotify_artist_info
# Out:
# {'artist_name': 'Zamdane',
#  'artist_id_spotify': '5CtPAGoxpJ4yLJLx6CSrO8',
#  'artist_uri_spotify': 'spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8',
#  'artist_link_picture_spotify': 'UNKNOWN',
#  'artist_genres_spotify': ['cloud rap francais',
#   'french hip hop',
#   'pop urbaine',
#   'rap conscient',
#   'rap francais'],
#  'artist_popularity_spotify': 60,
#  'artist_related_artists_spotify': ['Lesram',
#   'HOUDI',
#   'So La Lune',
#   'Rounhaa',
#   'Dau',
#   'Raplume',
#   'Stony Stone',
#   'Bekar',
#   'J9ueve',
#   'Wallace Cleaver',
#   'Yvnnis',
#   'Khali',
#   'BEN plg',
#   'Zed',
#   'Jeune Mort',
#   'ISHA',
#   'La Fève',
#   'BU$HI',
#   'Luv Resval',
#   'Prinzly'],
#  'artist_tracks': []}

# %%
def get_artist_albums(artist_id: str, album_types=['album', 'single']) -> list:
    """
    Retrieves all albums (including singles) of the artist with the given artist_id.
    :param artist_id: Spotify artist ID
    :param album_types: List of album types to retrieve, default is ['album', 'single']
    :return: List of all albums (including singles)
    """
    albums = []
    results = sp.artist_albums(artist_id, album_type=','.join(album_types), limit=50)
    
    while results:
        albums.extend(results['items'])
        if results['next']:
            results = sp.next(results)
        else:
            break
    
    # Remove duplicates by checking album ID
    unique_albums = {album['id']: album for album in albums}.values()
    
    return list(unique_albums)

def get_album_tracks(album_id: str) -> list:
    """
    Retrieves all tracks from a specific album using album_id.
    :param album_id: Spotify album ID
    :return: List of tracks in the album
    """
    tracks = []
    results = sp.album_tracks(album_id)
    
    while results:
        tracks.extend(results['items'])
        if results['next']:
            results = sp.next(results)
        else:
            break
    
    return tracks

def get_all_tracks_of_artist(artist_id: str) -> list:
    """
    Extracts all tracks (singles and part of albums) for a given artist.
    :param artist_id: Spotify artist ID
    :return: List of all tracks from the artist
    """
    all_tracks = []
    albums = get_artist_albums(artist_id)
    
    for album in albums:
        album_id = album['id']
        tracks = get_album_tracks(album_id)
        all_tracks.extend(tracks)
    
    return all_tracks

#  # Replace with the artist's Spotify ID
tracks = get_all_tracks_of_artist(spotify_artist_info['artist_id_spotify'])

# Display the track names
for idx, track in enumerate(tracks, start=1):

    spotify_artist_info['artist_tracks'].append(
        {
        "track_id_spotify": track['id'],
        "track_name": track['name'],
        "track_uri_spotify": track['uri'],
        "track_audio_features_spotify": sp.audio_features(track['id']) 
    })

# %%
for track_num, track in enumerate(spotify_artist_info['artist_tracks']):

    print(f"Track {track_num} - {track['track_name']}")
# Out:
# Track 0 - Mouchkila
# Track 1 - À ma guise
# Track 2 - Le grand cirque
# Track 3 - Million
# Track 4 - Printemps
# Track 5 - Alouette
# Track 6 - Boboalam
# Track 7 - Un peu de moi
# Track 8 - Youm wara youm
# Track 9 - Infini
# Track 10 - Stylo magique
# Track 11 - Loin d'ici
# Track 12 - Mélancolie criminelle
# Track 13 - Lalalala
# Track 14 - Audi GT
# Track 15 - Fleurs
# Track 16 - Si on s'aimait
# Track 17 - Noum
# Track 18 - Étoiles dans les yeux
# Track 19 - Monstres
# Track 20 - Tout ce qu'il voulait
# Track 21 - Le monde par ma fenêtre
# Track 22 - Incomplet comme février
# Track 23 - Boyka
# Track 24 - 1,2,3,4
# Track 25 - Stradivarius
# Track 26 - Naïf
# Track 27 - Fauves
# Track 28 - Même à distance on est proches
# Track 29 - Lettre à mon dieu
# Track 30 - Foust L'Bando
# Track 31 - Bonne année
# Track 32 - C18
# Track 33 - Zhar
# Track 34 - Groupie love
# Track 35 - Flouka
# Track 36 - Libre comme une colombe
# Track 37 - Vide quand t'es pas là
# Track 38 - Affamé #6 - Vital
# Track 39 - Affamé #7 - Histoires de la vraie vie
# Track 40 - Affamé #8 - Hayati
# Track 41 - Affamé #9 - GRRR
# Track 42 - Affamé #10 - Athéna
# Track 43 - Affamé #11 – Photogénique (Boosk’Affamé)
# Track 44 - Affamé #12 - Sentimental
# Track 45 - Affamé #13 - Marseille
# Track 46 - Médusa
# Track 47 - Ça y est, ça y est
# Track 48 - Salopard
# Track 49 - Cage dorée
# Track 50 - Favélas
# Track 51 - NTM
# Track 52 - Zéro
# Track 53 - Classe S
# Track 54 - Padmé
# Track 55 - Paradis
# Track 56 - Bulle
# Track 57 - Recommence
# Track 58 - Dans le noir
# Track 59 - Mémoire
# Track 60 - Pour mourir
# Track 61 - PP
# Track 62 - 7
# Track 63 - Ronaldinho
# Track 64 - Sablier
# Track 65 - Demain
# Track 66 - Deadstar
# Track 67 - Green
# Track 68 - Disaster
# Track 69 - Fallait
# Track 70 - Rolling Up
# Track 71 - Nil
# Track 72 - Mektoub
# Track 73 - Quand j'fume
# Track 74 - Synchtene
# Track 75 - Oh Mama
# Track 76 - Les zhommes
# Track 77 - Faya
# Track 78 - DOUTE (feat. Zamdane)
# Track 79 - Pilotes (feat. Zamdane)
# Track 80 - Absorber les larmes
# Track 81 - PAYSAGISTE
# Track 82 - Monstres
# Track 83 - Si on s'aimait
# Track 84 - Noum
# Track 85 - Mélancolie criminelle
# Track 86 - Loin d'ici
# Track 87 - DÎNER
# Track 88 - Youm wara youm
# Track 89 - Le grand cirque
# Track 90 - Boboalam
# Track 91 - Alouette
# Track 92 - Printemps
# Track 93 - Mélancolie criminelle - A COLORS SHOW
# Track 94 - Une éternité ne suffit pas (Affamé #22)
# Track 95 - Pièces manquantes
# Track 96 - MÉTÉORITE
# Track 97 - Cicatrice
# Track 98 - Formidable (Affamé #21)
# Track 99 - MOB (Affamé #20)
# Track 100 - BALLAD
# Track 101 - Ma réalité (Affamé #19)
# Track 102 - Bataille (Affamé #18)
# Track 103 - Angels (Affamé #17)
# Track 104 - Triste mais elle aime ça (Affamé #16)
# Track 105 - Conditionnés à décevoir (Affamé #15)
# Track 106 - Poussière (Affamé #14)
# Track 107 - J'arrête
# Track 108 - Un jour (feat. Zamdane)
# Track 109 - Sahara
# Track 110 - Soleil de ma vie
# Track 111 - P. Diddy (feat. Zamdane)
# Track 112 - Next Up France - S1-E1
# Track 113 - Avant la fin (feat. Zamdane)
# Track 114 - Sans toi
# Track 115 - Zenith
# Track 116 - PARADOXE (feat. Zamdane)
# Track 117 - Flouka
# Track 118 - Fauves
# Track 119 - Bonne année
# Track 120 - Incomplet comme février
# Track 121 - Le monde par ma fenêtre
# Track 122 - Boyka
# Track 123 - Zhar
# Track 124 - Décollage - Extrait de la BO de "Or Noir"
# Track 125 - Niya
# Track 126 - Affamé #13 - Marseille
# Track 127 - MRS
# Track 128 - Affamé #12 - Sentimental
# Track 129 - Affamé #11 – Photogénique (Boosk’Affamé)
# Track 130 - Affamé #10 - Athéna
# Track 131 - Affamé #9 - GRRR
# Track 132 - Affamé #8 - Hayati
# Track 133 - Affamé #7 - Histoires de la vraie vie
# Track 134 - Affamé #6 - Vital
# Track 135 - La fête
# Track 136 - NTM
# Track 137 - Zéro
# Track 138 - Classe S
# Track 139 - Padmé
# Track 140 - Paradis
# Track 141 - Potentiel (OM SESSIONS)
# Track 142 - Low
# Track 143 - Demain
# Track 144 - Recommence
# Track 145 - Affamé #1 - Shook
# Track 146 - Affamé #2 - 21
# Track 147 - Affamé #3 - No Party
# Track 148 - Affamé #4 - Survivant
# Track 149 - Affamé #5 - Seul
# Track 150 - Quand j'fume
# Track 151 - Green
# Track 152 - Disaster
# Track 153 - Passe à l'appart
# Track 154 - Dans L'mal
# Track 155 - Tjpc
# Track 156 - Règlement Freestyle #6
# Track 157 - Favaro

# %%
spotify_artist_song_data = pd.DataFrame(spotify_artist_info['artist_tracks'])

# %%
del spotify_artist_info['artist_tracks']
del spotify_artist_info['artist_related_artists_spotify']

# %%
spotify_artist_info
# Out:
# {'artist_name': 'Zamdane',
#  'artist_id_spotify': '5CtPAGoxpJ4yLJLx6CSrO8',
#  'artist_uri_spotify': 'spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8',
#  'artist_link_picture_spotify': 'UNKNOWN',
#  'artist_genres_spotify': ['cloud rap francais',
#   'french hip hop',
#   'pop urbaine',
#   'rap conscient',
#   'rap francais'],
#  'artist_popularity_spotify': 60,
#  'artist_related_artists_spotify': ['Lesram',
#   'HOUDI',
#   'So La Lune',
#   'Rounhaa',
#   'Dau',
#   'Raplume',
#   'Stony Stone',
#   'Bekar',
#   'J9ueve',
#   'Wallace Cleaver',
#   'Yvnnis',
#   'Khali',
#   'BEN plg',
#   'Zed',
#   'Jeune Mort',
#   'ISHA',
#   'La Fève',
#   'BU$HI',
#   'Luv Resval',
#   'Prinzly'],
#  'artist_tracks': [{'track_id_spotify': '0H8sSKJrB1xlmp5i0YgGrs',
#    'track_name': 'Mouchkila',
#    'track_uri_spotify': 'spotify:track:0H8sSKJrB1xlmp5i0YgGrs',
#    'track_audio_features_spotify': [{'danceability': 0.6,
#      'energy': 0.499,
#      'key': 5,
#      'loudness': -7.57,
#      'mode': 0,
#      'speechiness': 0.0364,
#      'acousticness': 0.673,
#      'instrumentalness': 0,
#      'liveness': 0.269,
#      'valence': 0.578,
#      'tempo': 160.073,
#      'type': 'audio_features',
#      'id': '0H8sSKJrB1xlmp5i0YgGrs',
#      'uri': 'spotify:track:0H8sSKJrB1xlmp5i0YgGrs',
#      'track_href': 'https://api.spotify.com/v1/tracks/0H8sSKJrB1xlmp5i0YgGrs',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0H8sSKJrB1xlmp5i0YgGrs',
#      'duration_ms': 226413,
#      'time_signature': 4}]},
#   {'track_id_spotify': '1HaOYE4mMGG49HOf98uLTD',
#    'track_name': 'À ma guise',
#    'track_uri_spotify': 'spotify:track:1HaOYE4mMGG49HOf98uLTD',
#    'track_audio_features_spotify': [{'danceability': 0.706,
#      'energy': 0.618,
#      'key': 4,
#      'loudness': -6.832,
#      'mode': 0,
#      'speechiness': 0.0828,
#      'acousticness': 0.634,
#      'instrumentalness': 7.64e-05,
#      'liveness': 0.0907,
#      'valence': 0.349,
#      'tempo': 137.988,
#      'type': 'audio_features',
#      'id': '1HaOYE4mMGG49HOf98uLTD',
#      'uri': 'spotify:track:1HaOYE4mMGG49HOf98uLTD',
#      'track_href': 'https://api.spotify.com/v1/tracks/1HaOYE4mMGG49HOf98uLTD',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HaOYE4mMGG49HOf98uLTD',
#      'duration_ms': 161773,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2lk8jLE8cF7NSL50pOXoTF',
#    'track_name': 'Le grand cirque',
#    'track_uri_spotify': 'spotify:track:2lk8jLE8cF7NSL50pOXoTF',
#    'track_audio_features_spotify': [{'danceability': 0.619,
#      'energy': 0.323,
#      'key': 3,
#      'loudness': -7.642,
#      'mode': 0,
#      'speechiness': 0.0379,
#      'acousticness': 0.464,
#      'instrumentalness': 4.15e-05,
#      'liveness': 0.206,
#      'valence': 0.369,
#      'tempo': 130.008,
#      'type': 'audio_features',
#      'id': '2lk8jLE8cF7NSL50pOXoTF',
#      'uri': 'spotify:track:2lk8jLE8cF7NSL50pOXoTF',
#      'track_href': 'https://api.spotify.com/v1/tracks/2lk8jLE8cF7NSL50pOXoTF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lk8jLE8cF7NSL50pOXoTF',
#      'duration_ms': 241760,
#      'time_signature': 5}]},
#   {'track_id_spotify': '33GQLlkZsYNw569Pr0ZAXw',
#    'track_name': 'Million',
#    'track_uri_spotify': 'spotify:track:33GQLlkZsYNw569Pr0ZAXw',
#    'track_audio_features_spotify': [{'danceability': 0.746,
#      'energy': 0.498,
#      'key': 9,
#      'loudness': -9.168,
#      'mode': 0,
#      'speechiness': 0.0632,
#      'acousticness': 0.796,
#      'instrumentalness': 0,
#      'liveness': 0.0946,
#      'valence': 0.777,
#      'tempo': 131.975,
#      'type': 'audio_features',
#      'id': '33GQLlkZsYNw569Pr0ZAXw',
#      'uri': 'spotify:track:33GQLlkZsYNw569Pr0ZAXw',
#      'track_href': 'https://api.spotify.com/v1/tracks/33GQLlkZsYNw569Pr0ZAXw',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33GQLlkZsYNw569Pr0ZAXw',
#      'duration_ms': 211493,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5lV989DHPY9NO7ygRAAG2r',
#    'track_name': 'Printemps',
#    'track_uri_spotify': 'spotify:track:5lV989DHPY9NO7ygRAAG2r',
#    'track_audio_features_spotify': [{'danceability': 0.687,
#      'energy': 0.696,
#      'key': 1,
#      'loudness': -6.757,
#      'mode': 0,
#      'speechiness': 0.0649,
#      'acousticness': 0.261,
#      'instrumentalness': 0,
#      'liveness': 0.105,
#      'valence': 0.446,
#      'tempo': 112.933,
#      'type': 'audio_features',
#      'id': '5lV989DHPY9NO7ygRAAG2r',
#      'uri': 'spotify:track:5lV989DHPY9NO7ygRAAG2r',
#      'track_href': 'https://api.spotify.com/v1/tracks/5lV989DHPY9NO7ygRAAG2r',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lV989DHPY9NO7ygRAAG2r',
#      'duration_ms': 193373,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4XcEqNoiGsC7eTEagZ9iwA',
#    'track_name': 'Alouette',
#    'track_uri_spotify': 'spotify:track:4XcEqNoiGsC7eTEagZ9iwA',
#    'track_audio_features_spotify': [{'danceability': 0.789,
#      'energy': 0.556,
#      'key': 3,
#      'loudness': -8.382,
#      'mode': 0,
#      'speechiness': 0.147,
#      'acousticness': 0.394,
#      'instrumentalness': 1.47e-06,
#      'liveness': 0.0972,
#      'valence': 0.461,
#      'tempo': 130.026,
#      'type': 'audio_features',
#      'id': '4XcEqNoiGsC7eTEagZ9iwA',
#      'uri': 'spotify:track:4XcEqNoiGsC7eTEagZ9iwA',
#      'track_href': 'https://api.spotify.com/v1/tracks/4XcEqNoiGsC7eTEagZ9iwA',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XcEqNoiGsC7eTEagZ9iwA',
#      'duration_ms': 222973,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0CxkghH2XufHbbuNk5y7SX',
#    'track_name': 'Boboalam',
#    'track_uri_spotify': 'spotify:track:0CxkghH2XufHbbuNk5y7SX',
#    'track_audio_features_spotify': [{'danceability': 0.671,
#      'energy': 0.556,
#      'key': 4,
#      'loudness': -8.817,
#      'mode': 0,
#      'speechiness': 0.0474,
#      'acousticness': 0.354,
#      'instrumentalness': 0,
#      'liveness': 0.159,
#      'valence': 0.187,
#      'tempo': 129.949,
#      'type': 'audio_features',
#      'id': '0CxkghH2XufHbbuNk5y7SX',
#      'uri': 'spotify:track:0CxkghH2XufHbbuNk5y7SX',
#      'track_href': 'https://api.spotify.com/v1/tracks/0CxkghH2XufHbbuNk5y7SX',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CxkghH2XufHbbuNk5y7SX',
#      'duration_ms': 169747,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5fP524HRhEk14cI1xQFCZ4',
#    'track_name': 'Un peu de moi',
#    'track_uri_spotify': 'spotify:track:5fP524HRhEk14cI1xQFCZ4',
#    'track_audio_features_spotify': [{'danceability': 0.739,
#      'energy': 0.338,
#      'key': 11,
#      'loudness': -8.006,
#      'mode': 0,
#      'speechiness': 0.0436,
#      'acousticness': 0.667,
#      'instrumentalness': 0,
#      'liveness': 0.126,
#      'valence': 0.32,
#      'tempo': 136.078,
#      'type': 'audio_features',
#      'id': '5fP524HRhEk14cI1xQFCZ4',
#      'uri': 'spotify:track:5fP524HRhEk14cI1xQFCZ4',
#      'track_href': 'https://api.spotify.com/v1/tracks/5fP524HRhEk14cI1xQFCZ4',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fP524HRhEk14cI1xQFCZ4',
#      'duration_ms': 199227,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3EXxu59VTeuaKBGsLQFwBf',
#    'track_name': 'Youm wara youm',
#    'track_uri_spotify': 'spotify:track:3EXxu59VTeuaKBGsLQFwBf',
#    'track_audio_features_spotify': [{'danceability': 0.708,
#      'energy': 0.582,
#      'key': 3,
#      'loudness': -7.018,
#      'mode': 0,
#      'speechiness': 0.0691,
#      'acousticness': 0.225,
#      'instrumentalness': 0,
#      'liveness': 0.177,
#      'valence': 0.297,
#      'tempo': 139.985,
#      'type': 'audio_features',
#      'id': '3EXxu59VTeuaKBGsLQFwBf',
#      'uri': 'spotify:track:3EXxu59VTeuaKBGsLQFwBf',
#      'track_href': 'https://api.spotify.com/v1/tracks/3EXxu59VTeuaKBGsLQFwBf',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EXxu59VTeuaKBGsLQFwBf',
#      'duration_ms': 220173,
#      'time_signature': 4}]},
#   {'track_id_spotify': '1UxeNGpZBqu4DuywYLk8n2',
#    'track_name': 'Infini',
#    'track_uri_spotify': 'spotify:track:1UxeNGpZBqu4DuywYLk8n2',
#    'track_audio_features_spotify': [{'danceability': 0.686,
#      'energy': 0.583,
#      'key': 3,
#      'loudness': -7.133,
#      'mode': 0,
#      'speechiness': 0.0706,
#      'acousticness': 0.684,
#      'instrumentalness': 0,
#      'liveness': 0.124,
#      'valence': 0.571,
#      'tempo': 144.006,
#      'type': 'audio_features',
#      'id': '1UxeNGpZBqu4DuywYLk8n2',
#      'uri': 'spotify:track:1UxeNGpZBqu4DuywYLk8n2',
#      'track_href': 'https://api.spotify.com/v1/tracks/1UxeNGpZBqu4DuywYLk8n2',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UxeNGpZBqu4DuywYLk8n2',
#      'duration_ms': 162573,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6PY11Qu4WQhGyYioJe3eoJ',
#    'track_name': 'Stylo magique',
#    'track_uri_spotify': 'spotify:track:6PY11Qu4WQhGyYioJe3eoJ',
#    'track_audio_features_spotify': [{'danceability': 0.402,
#      'energy': 0.534,
#      'key': 4,
#      'loudness': -8.347,
#      'mode': 1,
#      'speechiness': 0.0501,
#      'acousticness': 0.751,
#      'instrumentalness': 0,
#      'liveness': 0.158,
#      'valence': 0.09,
#      'tempo': 130.881,
#      'type': 'audio_features',
#      'id': '6PY11Qu4WQhGyYioJe3eoJ',
#      'uri': 'spotify:track:6PY11Qu4WQhGyYioJe3eoJ',
#      'track_href': 'https://api.spotify.com/v1/tracks/6PY11Qu4WQhGyYioJe3eoJ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PY11Qu4WQhGyYioJe3eoJ',
#      'duration_ms': 198893,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0yvtWcKzMjrMfwBwQYXAi1',
#    'track_name': "Loin d'ici",
#    'track_uri_spotify': 'spotify:track:0yvtWcKzMjrMfwBwQYXAi1',
#    'track_audio_features_spotify': [{'danceability': 0.817,
#      'energy': 0.673,
#      'key': 8,
#      'loudness': -5.982,
#      'mode': 0,
#      'speechiness': 0.0903,
#      'acousticness': 0.554,
#      'instrumentalness': 0,
#      'liveness': 0.183,
#      'valence': 0.499,
#      'tempo': 119.968,
#      'type': 'audio_features',
#      'id': '0yvtWcKzMjrMfwBwQYXAi1',
#      'uri': 'spotify:track:0yvtWcKzMjrMfwBwQYXAi1',
#      'track_href': 'https://api.spotify.com/v1/tracks/0yvtWcKzMjrMfwBwQYXAi1',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yvtWcKzMjrMfwBwQYXAi1',
#      'duration_ms': 203720,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5dJHoH4QwIs0uYqMgJoVKm',
#    'track_name': 'Mélancolie criminelle',
#    'track_uri_spotify': 'spotify:track:5dJHoH4QwIs0uYqMgJoVKm',
#    'track_audio_features_spotify': [{'danceability': 0.503,
#      'energy': 0.292,
#      'key': 2,
#      'loudness': -11.445,
#      'mode': 0,
#      'speechiness': 0.0601,
#      'acousticness': 0.9,
#      'instrumentalness': 0,
#      'liveness': 0.103,
#      'valence': 0.287,
#      'tempo': 134.233,
#      'type': 'audio_features',
#      'id': '5dJHoH4QwIs0uYqMgJoVKm',
#      'uri': 'spotify:track:5dJHoH4QwIs0uYqMgJoVKm',
#      'track_href': 'https://api.spotify.com/v1/tracks/5dJHoH4QwIs0uYqMgJoVKm',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dJHoH4QwIs0uYqMgJoVKm',
#      'duration_ms': 196747,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6lwqyDPOufSHFYPOrKeA6y',
#    'track_name': 'Lalalala',
#    'track_uri_spotify': 'spotify:track:6lwqyDPOufSHFYPOrKeA6y',
#    'track_audio_features_spotify': [{'danceability': 0.821,
#      'energy': 0.738,
#      'key': 11,
#      'loudness': -5.451,
#      'mode': 0,
#      'speechiness': 0.0382,
#      'acousticness': 0.466,
#      'instrumentalness': 3.44e-05,
#      'liveness': 0.103,
#      'valence': 0.379,
#      'tempo': 109.975,
#      'type': 'audio_features',
#      'id': '6lwqyDPOufSHFYPOrKeA6y',
#      'uri': 'spotify:track:6lwqyDPOufSHFYPOrKeA6y',
#      'track_href': 'https://api.spotify.com/v1/tracks/6lwqyDPOufSHFYPOrKeA6y',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lwqyDPOufSHFYPOrKeA6y',
#      'duration_ms': 210453,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0iC047atkO104cV7EjOxmg',
#    'track_name': 'Audi GT',
#    'track_uri_spotify': 'spotify:track:0iC047atkO104cV7EjOxmg',
#    'track_audio_features_spotify': [{'danceability': 0.492,
#      'energy': 0.552,
#      'key': 4,
#      'loudness': -6.713,
#      'mode': 0,
#      'speechiness': 0.0399,
#      'acousticness': 0.622,
#      'instrumentalness': 0,
#      'liveness': 0.304,
#      'valence': 0.126,
#      'tempo': 130.134,
#      'type': 'audio_features',
#      'id': '0iC047atkO104cV7EjOxmg',
#      'uri': 'spotify:track:0iC047atkO104cV7EjOxmg',
#      'track_href': 'https://api.spotify.com/v1/tracks/0iC047atkO104cV7EjOxmg',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iC047atkO104cV7EjOxmg',
#      'duration_ms': 237627,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2jrpnXUN8mMrDMKXrzKsNO',
#    'track_name': 'Fleurs',
#    'track_uri_spotify': 'spotify:track:2jrpnXUN8mMrDMKXrzKsNO',
#    'track_audio_features_spotify': [{'danceability': 0.512,
#      'energy': 0.821,
#      'key': 8,
#      'loudness': -5.838,
#      'mode': 0,
#      'speechiness': 0.132,
#      'acousticness': 0.728,
#      'instrumentalness': 0.00244,
#      'liveness': 0.0988,
#      'valence': 0.332,
#      'tempo': 107.427,
#      'type': 'audio_features',
#      'id': '2jrpnXUN8mMrDMKXrzKsNO',
#      'uri': 'spotify:track:2jrpnXUN8mMrDMKXrzKsNO',
#      'track_href': 'https://api.spotify.com/v1/tracks/2jrpnXUN8mMrDMKXrzKsNO',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jrpnXUN8mMrDMKXrzKsNO',
#      'duration_ms': 185453,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6OFtmuxkljWd76OuWL8fL6',
#    'track_name': "Si on s'aimait",
#    'track_uri_spotify': 'spotify:track:6OFtmuxkljWd76OuWL8fL6',
#    'track_audio_features_spotify': [{'danceability': 0.65,
#      'energy': 0.465,
#      'key': 0,
#      'loudness': -9.599,
#      'mode': 0,
#      'speechiness': 0.034,
#      'acousticness': 0.66,
#      'instrumentalness': 2.29e-06,
#      'liveness': 0.127,
#      'valence': 0.433,
#      'tempo': 135.084,
#      'type': 'audio_features',
#      'id': '6OFtmuxkljWd76OuWL8fL6',
#      'uri': 'spotify:track:6OFtmuxkljWd76OuWL8fL6',
#      'track_href': 'https://api.spotify.com/v1/tracks/6OFtmuxkljWd76OuWL8fL6',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OFtmuxkljWd76OuWL8fL6',
#      'duration_ms': 199987,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2EuEZWoUseZpMH1vGv3XRd',
#    'track_name': 'Noum',
#    'track_uri_spotify': 'spotify:track:2EuEZWoUseZpMH1vGv3XRd',
#    'track_audio_features_spotify': [{'danceability': 0.692,
#      'energy': 0.551,
#      'key': 8,
#      'loudness': -8.357,
#      'mode': 0,
#      'speechiness': 0.0532,
#      'acousticness': 0.707,
#      'instrumentalness': 0,
#      'liveness': 0.181,
#      'valence': 0.474,
#      'tempo': 119.844,
#      'type': 'audio_features',
#      'id': '2EuEZWoUseZpMH1vGv3XRd',
#      'uri': 'spotify:track:2EuEZWoUseZpMH1vGv3XRd',
#      'track_href': 'https://api.spotify.com/v1/tracks/2EuEZWoUseZpMH1vGv3XRd',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2EuEZWoUseZpMH1vGv3XRd',
#      'duration_ms': 187307,
#      'time_signature': 4}]},
#   {'track_id_spotify': '1QrlezFvTcpYE3EOAUfANe',
#    'track_name': 'Étoiles dans les yeux',
#    'track_uri_spotify': 'spotify:track:1QrlezFvTcpYE3EOAUfANe',
#    'track_audio_features_spotify': [{'danceability': 0.742,
#      'energy': 0.492,
#      'key': 11,
#      'loudness': -6.461,
#      'mode': 0,
#      'speechiness': 0.0819,
#      'acousticness': 0.456,
#      'instrumentalness': 0,
#      'liveness': 0.164,
#      'valence': 0.506,
#      'tempo': 140.048,
#      'type': 'audio_features',
#      'id': '1QrlezFvTcpYE3EOAUfANe',
#      'uri': 'spotify:track:1QrlezFvTcpYE3EOAUfANe',
#      'track_href': 'https://api.spotify.com/v1/tracks/1QrlezFvTcpYE3EOAUfANe',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1QrlezFvTcpYE3EOAUfANe',
#      'duration_ms': 193227,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3JUQ8TH8SirjNyeiCmHrKS',
#    'track_name': 'Monstres',
#    'track_uri_spotify': 'spotify:track:3JUQ8TH8SirjNyeiCmHrKS',
#    'track_audio_features_spotify': [{'danceability': 0.478,
#      'energy': 0.474,
#      'key': 11,
#      'loudness': -8.944,
#      'mode': 0,
#      'speechiness': 0.0445,
#      'acousticness': 0.792,
#      'instrumentalness': 0,
#      'liveness': 0.1,
#      'valence': 0.576,
#      'tempo': 139.759,
#      'type': 'audio_features',
#      'id': '3JUQ8TH8SirjNyeiCmHrKS',
#      'uri': 'spotify:track:3JUQ8TH8SirjNyeiCmHrKS',
#      'track_href': 'https://api.spotify.com/v1/tracks/3JUQ8TH8SirjNyeiCmHrKS',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JUQ8TH8SirjNyeiCmHrKS',
#      'duration_ms': 183733,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6mCNZv1jxTcM4rxR9Zm4sA',
#    'track_name': "Tout ce qu'il voulait",
#    'track_uri_spotify': 'spotify:track:6mCNZv1jxTcM4rxR9Zm4sA',
#    'track_audio_features_spotify': [{'danceability': 0.752,
#      'energy': 0.527,
#      'key': 1,
#      'loudness': -7.886,
#      'mode': 0,
#      'speechiness': 0.0449,
#      'acousticness': 0.159,
#      'instrumentalness': 5.48e-05,
#      'liveness': 0.09,
#      'valence': 0.552,
#      'tempo': 120.019,
#      'type': 'audio_features',
#      'id': '6mCNZv1jxTcM4rxR9Zm4sA',
#      'uri': 'spotify:track:6mCNZv1jxTcM4rxR9Zm4sA',
#      'track_href': 'https://api.spotify.com/v1/tracks/6mCNZv1jxTcM4rxR9Zm4sA',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mCNZv1jxTcM4rxR9Zm4sA',
#      'duration_ms': 212893,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4kgTlSy5uGGe8rgq0ANV69',
#    'track_name': 'Le monde par ma fenêtre',
#    'track_uri_spotify': 'spotify:track:4kgTlSy5uGGe8rgq0ANV69',
#    'track_audio_features_spotify': [{'danceability': 0.523,
#      'energy': 0.555,
#      'key': 3,
#      'loudness': -7.75,
#      'mode': 0,
#      'speechiness': 0.078,
#      'acousticness': 0.588,
#      'instrumentalness': 0,
#      'liveness': 0.112,
#      'valence': 0.643,
#      'tempo': 185.909,
#      'type': 'audio_features',
#      'id': '4kgTlSy5uGGe8rgq0ANV69',
#      'uri': 'spotify:track:4kgTlSy5uGGe8rgq0ANV69',
#      'track_href': 'https://api.spotify.com/v1/tracks/4kgTlSy5uGGe8rgq0ANV69',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kgTlSy5uGGe8rgq0ANV69',
#      'duration_ms': 201987,
#      'time_signature': 3}]},
#   {'track_id_spotify': '2GBYcpv1FsTS4SGc1eGr5g',
#    'track_name': 'Incomplet comme février',
#    'track_uri_spotify': 'spotify:track:2GBYcpv1FsTS4SGc1eGr5g',
#    'track_audio_features_spotify': [{'danceability': 0.849,
#      'energy': 0.521,
#      'key': 7,
#      'loudness': -8.971,
#      'mode': 0,
#      'speechiness': 0.171,
#      'acousticness': 0.169,
#      'instrumentalness': 0,
#      'liveness': 0.104,
#      'valence': 0.337,
#      'tempo': 140.108,
#      'type': 'audio_features',
#      'id': '2GBYcpv1FsTS4SGc1eGr5g',
#      'uri': 'spotify:track:2GBYcpv1FsTS4SGc1eGr5g',
#      'track_href': 'https://api.spotify.com/v1/tracks/2GBYcpv1FsTS4SGc1eGr5g',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GBYcpv1FsTS4SGc1eGr5g',
#      'duration_ms': 210667,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6trUdO3Ns8kyvePntgMGUW',
#    'track_name': 'Boyka',
#    'track_uri_spotify': 'spotify:track:6trUdO3Ns8kyvePntgMGUW',
#    'track_audio_features_spotify': [{'danceability': 0.577,
#      'energy': 0.708,
#      'key': 4,
#      'loudness': -5.883,
#      'mode': 0,
#      'speechiness': 0.189,
#      'acousticness': 0.31,
#      'instrumentalness': 0,
#      'liveness': 0.301,
#      'valence': 0.634,
#      'tempo': 124.92,
#      'type': 'audio_features',
#      'id': '6trUdO3Ns8kyvePntgMGUW',
#      'uri': 'spotify:track:6trUdO3Ns8kyvePntgMGUW',
#      'track_href': 'https://api.spotify.com/v1/tracks/6trUdO3Ns8kyvePntgMGUW',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6trUdO3Ns8kyvePntgMGUW',
#      'duration_ms': 221987,
#      'time_signature': 4}]},
#   {'track_id_spotify': '659Nz6xHkTvObWLup9MZ9g',
#    'track_name': '1,2,3,4',
#    'track_uri_spotify': 'spotify:track:659Nz6xHkTvObWLup9MZ9g',
#    'track_audio_features_spotify': [{'danceability': 0.625,
#      'energy': 0.528,
#      'key': 4,
#      'loudness': -8.52,
#      'mode': 0,
#      'speechiness': 0.0479,
#      'acousticness': 0.452,
#      'instrumentalness': 0.000264,
#      'liveness': 0.077,
#      'valence': 0.285,
#      'tempo': 125.005,
#      'type': 'audio_features',
#      'id': '659Nz6xHkTvObWLup9MZ9g',
#      'uri': 'spotify:track:659Nz6xHkTvObWLup9MZ9g',
#      'track_href': 'https://api.spotify.com/v1/tracks/659Nz6xHkTvObWLup9MZ9g',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/659Nz6xHkTvObWLup9MZ9g',
#      'duration_ms': 208000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5N4qY6MmyKyoj0i8N0UqoM',
#    'track_name': 'Stradivarius',
#    'track_uri_spotify': 'spotify:track:5N4qY6MmyKyoj0i8N0UqoM',
#    'track_audio_features_spotify': [{'danceability': 0.564,
#      'energy': 0.626,
#      'key': 1,
#      'loudness': -7.684,
#      'mode': 0,
#      'speechiness': 0.33,
#      'acousticness': 0.304,
#      'instrumentalness': 0,
#      'liveness': 0.314,
#      'valence': 0.228,
#      'tempo': 140.101,
#      'type': 'audio_features',
#      'id': '5N4qY6MmyKyoj0i8N0UqoM',
#      'uri': 'spotify:track:5N4qY6MmyKyoj0i8N0UqoM',
#      'track_href': 'https://api.spotify.com/v1/tracks/5N4qY6MmyKyoj0i8N0UqoM',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5N4qY6MmyKyoj0i8N0UqoM',
#      'duration_ms': 179987,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3akdJl2W5slpvla8O9jJEM',
#    'track_name': 'Naïf',
#    'track_uri_spotify': 'spotify:track:3akdJl2W5slpvla8O9jJEM',
#    'track_audio_features_spotify': [{'danceability': 0.612,
#      'energy': 0.378,
#      'key': 9,
#      'loudness': -9.062,
#      'mode': 0,
#      'speechiness': 0.027,
#      'acousticness': 0.947,
#      'instrumentalness': 1.02e-06,
#      'liveness': 0.089,
#      'valence': 0.284,
#      'tempo': 131.907,
#      'type': 'audio_features',
#      'id': '3akdJl2W5slpvla8O9jJEM',
#      'uri': 'spotify:track:3akdJl2W5slpvla8O9jJEM',
#      'track_href': 'https://api.spotify.com/v1/tracks/3akdJl2W5slpvla8O9jJEM',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3akdJl2W5slpvla8O9jJEM',
#      'duration_ms': 206880,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5lyKwmMB1nuU3jUrrIFI3Q',
#    'track_name': 'Fauves',
#    'track_uri_spotify': 'spotify:track:5lyKwmMB1nuU3jUrrIFI3Q',
#    'track_audio_features_spotify': [{'danceability': 0.812,
#      'energy': 0.618,
#      'key': 0,
#      'loudness': -7.228,
#      'mode': 1,
#      'speechiness': 0.235,
#      'acousticness': 0.313,
#      'instrumentalness': 0,
#      'liveness': 0.121,
#      'valence': 0.462,
#      'tempo': 136.954,
#      'type': 'audio_features',
#      'id': '5lyKwmMB1nuU3jUrrIFI3Q',
#      'uri': 'spotify:track:5lyKwmMB1nuU3jUrrIFI3Q',
#      'track_href': 'https://api.spotify.com/v1/tracks/5lyKwmMB1nuU3jUrrIFI3Q',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lyKwmMB1nuU3jUrrIFI3Q',
#      'duration_ms': 210453,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2GX891mqt3628pvJbTki81',
#    'track_name': 'Même à distance on est proches',
#    'track_uri_spotify': 'spotify:track:2GX891mqt3628pvJbTki81',
#    'track_audio_features_spotify': [{'danceability': 0.846,
#      'energy': 0.575,
#      'key': 8,
#      'loudness': -8.548,
#      'mode': 0,
#      'speechiness': 0.258,
#      'acousticness': 0.438,
#      'instrumentalness': 1.48e-06,
#      'liveness': 0.0967,
#      'valence': 0.62,
#      'tempo': 131.933,
#      'type': 'audio_features',
#      'id': '2GX891mqt3628pvJbTki81',
#      'uri': 'spotify:track:2GX891mqt3628pvJbTki81',
#      'track_href': 'https://api.spotify.com/v1/tracks/2GX891mqt3628pvJbTki81',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GX891mqt3628pvJbTki81',
#      'duration_ms': 120040,
#      'time_signature': 4}]},
#   {'track_id_spotify': '33WcCJTMnB9hGDr9CrStBv',
#    'track_name': 'Lettre à mon dieu',
#    'track_uri_spotify': 'spotify:track:33WcCJTMnB9hGDr9CrStBv',
#    'track_audio_features_spotify': [{'danceability': 0.622,
#      'energy': 0.624,
#      'key': 0,
#      'loudness': -8.724,
#      'mode': 1,
#      'speechiness': 0.0453,
#      'acousticness': 0.674,
#      'instrumentalness': 0.000516,
#      'liveness': 0.0676,
#      'valence': 0.233,
#      'tempo': 93.074,
#      'type': 'audio_features',
#      'id': '33WcCJTMnB9hGDr9CrStBv',
#      'uri': 'spotify:track:33WcCJTMnB9hGDr9CrStBv',
#      'track_href': 'https://api.spotify.com/v1/tracks/33WcCJTMnB9hGDr9CrStBv',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33WcCJTMnB9hGDr9CrStBv',
#      'duration_ms': 200173,
#      'time_signature': 4}]},
#   {'track_id_spotify': '67CAY7Mmyek5iVB5oVJvVZ',
#    'track_name': "Foust L'Bando",
#    'track_uri_spotify': 'spotify:track:67CAY7Mmyek5iVB5oVJvVZ',
#    'track_audio_features_spotify': [{'danceability': 0.572,
#      'energy': 0.454,
#      'key': 1,
#      'loudness': -9.222,
#      'mode': 0,
#      'speechiness': 0.0882,
#      'acousticness': 0.621,
#      'instrumentalness': 0,
#      'liveness': 0.11,
#      'valence': 0.232,
#      'tempo': 139.87,
#      'type': 'audio_features',
#      'id': '67CAY7Mmyek5iVB5oVJvVZ',
#      'uri': 'spotify:track:67CAY7Mmyek5iVB5oVJvVZ',
#      'track_href': 'https://api.spotify.com/v1/tracks/67CAY7Mmyek5iVB5oVJvVZ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67CAY7Mmyek5iVB5oVJvVZ',
#      'duration_ms': 182173,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2bo2UNuag7NYEYu3TAmzpb',
#    'track_name': 'Bonne année',
#    'track_uri_spotify': 'spotify:track:2bo2UNuag7NYEYu3TAmzpb',
#    'track_audio_features_spotify': [{'danceability': 0.685,
#      'energy': 0.605,
#      'key': 0,
#      'loudness': -6.453,
#      'mode': 0,
#      'speechiness': 0.127,
#      'acousticness': 0.675,
#      'instrumentalness': 0,
#      'liveness': 0.272,
#      'valence': 0.652,
#      'tempo': 139.883,
#      'type': 'audio_features',
#      'id': '2bo2UNuag7NYEYu3TAmzpb',
#      'uri': 'spotify:track:2bo2UNuag7NYEYu3TAmzpb',
#      'track_href': 'https://api.spotify.com/v1/tracks/2bo2UNuag7NYEYu3TAmzpb',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bo2UNuag7NYEYu3TAmzpb',
#      'duration_ms': 214000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '57lcVv1vMs8DNCkONAbzEA',
#    'track_name': 'C18',
#    'track_uri_spotify': 'spotify:track:57lcVv1vMs8DNCkONAbzEA',
#    'track_audio_features_spotify': [{'danceability': 0.83,
#      'energy': 0.587,
#      'key': 6,
#      'loudness': -6.909,
#      'mode': 0,
#      'speechiness': 0.0488,
#      'acousticness': 0.457,
#      'instrumentalness': 0.000764,
#      'liveness': 0.131,
#      'valence': 0.341,
#      'tempo': 120.001,
#      'type': 'audio_features',
#      'id': '57lcVv1vMs8DNCkONAbzEA',
#      'uri': 'spotify:track:57lcVv1vMs8DNCkONAbzEA',
#      'track_href': 'https://api.spotify.com/v1/tracks/57lcVv1vMs8DNCkONAbzEA',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57lcVv1vMs8DNCkONAbzEA',
#      'duration_ms': 146160,
#      'time_signature': 4}]},
#   {'track_id_spotify': '44NvGkg7HTYTAwOr6XVl14',
#    'track_name': 'Zhar',
#    'track_uri_spotify': 'spotify:track:44NvGkg7HTYTAwOr6XVl14',
#    'track_audio_features_spotify': [{'danceability': 0.666,
#      'energy': 0.657,
#      'key': 8,
#      'loudness': -7.003,
#      'mode': 1,
#      'speechiness': 0.122,
#      'acousticness': 0.193,
#      'instrumentalness': 0,
#      'liveness': 0.255,
#      'valence': 0.346,
#      'tempo': 94.912,
#      'type': 'audio_features',
#      'id': '44NvGkg7HTYTAwOr6XVl14',
#      'uri': 'spotify:track:44NvGkg7HTYTAwOr6XVl14',
#      'track_href': 'https://api.spotify.com/v1/tracks/44NvGkg7HTYTAwOr6XVl14',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44NvGkg7HTYTAwOr6XVl14',
#      'duration_ms': 166360,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3jcAPpfa4rI3UKesaNge2c',
#    'track_name': 'Groupie love',
#    'track_uri_spotify': 'spotify:track:3jcAPpfa4rI3UKesaNge2c',
#    'track_audio_features_spotify': [{'danceability': 0.7,
#      'energy': 0.387,
#      'key': 1,
#      'loudness': -9.961,
#      'mode': 1,
#      'speechiness': 0.0393,
#      'acousticness': 0.698,
#      'instrumentalness': 0.000156,
#      'liveness': 0.0712,
#      'valence': 0.4,
#      'tempo': 99.981,
#      'type': 'audio_features',
#      'id': '3jcAPpfa4rI3UKesaNge2c',
#      'uri': 'spotify:track:3jcAPpfa4rI3UKesaNge2c',
#      'track_href': 'https://api.spotify.com/v1/tracks/3jcAPpfa4rI3UKesaNge2c',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3jcAPpfa4rI3UKesaNge2c',
#      'duration_ms': 197880,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4lFxT7BnIpfhPhwpMRa1y4',
#    'track_name': 'Flouka',
#    'track_uri_spotify': 'spotify:track:4lFxT7BnIpfhPhwpMRa1y4',
#    'track_audio_features_spotify': [{'danceability': 0.484,
#      'energy': 0.687,
#      'key': 1,
#      'loudness': -6.368,
#      'mode': 0,
#      'speechiness': 0.0822,
#      'acousticness': 0.568,
#      'instrumentalness': 4.68e-06,
#      'liveness': 0.0666,
#      'valence': 0.641,
#      'tempo': 119.015,
#      'type': 'audio_features',
#      'id': '4lFxT7BnIpfhPhwpMRa1y4',
#      'uri': 'spotify:track:4lFxT7BnIpfhPhwpMRa1y4',
#      'track_href': 'https://api.spotify.com/v1/tracks/4lFxT7BnIpfhPhwpMRa1y4',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lFxT7BnIpfhPhwpMRa1y4',
#      'duration_ms': 188693,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6BaIMGpVXZ84s6VeEECswF',
#    'track_name': 'Libre comme une colombe',
#    'track_uri_spotify': 'spotify:track:6BaIMGpVXZ84s6VeEECswF',
#    'track_audio_features_spotify': [{'danceability': 0.829,
#      'energy': 0.433,
#      'key': 9,
#      'loudness': -8.0,
#      'mode': 1,
#      'speechiness': 0.0709,
#      'acousticness': 0.157,
#      'instrumentalness': 0,
#      'liveness': 0.111,
#      'valence': 0.498,
#      'tempo': 133.056,
#      'type': 'audio_features',
#      'id': '6BaIMGpVXZ84s6VeEECswF',
#      'uri': 'spotify:track:6BaIMGpVXZ84s6VeEECswF',
#      'track_href': 'https://api.spotify.com/v1/tracks/6BaIMGpVXZ84s6VeEECswF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BaIMGpVXZ84s6VeEECswF',
#      'duration_ms': 146173,
#      'time_signature': 4}]},
#   {'track_id_spotify': '7rO0JMFQtmsyZxlqH5g9ET',
#    'track_name': "Vide quand t'es pas là",
#    'track_uri_spotify': 'spotify:track:7rO0JMFQtmsyZxlqH5g9ET',
#    'track_audio_features_spotify': [{'danceability': 0.661,
#      'energy': 0.28,
#      'key': 11,
#      'loudness': -12.758,
#      'mode': 0,
#      'speechiness': 0.04,
#      'acousticness': 0.768,
#      'instrumentalness': 0,
#      'liveness': 0.122,
#      'valence': 0.374,
#      'tempo': 97.053,
#      'type': 'audio_features',
#      'id': '7rO0JMFQtmsyZxlqH5g9ET',
#      'uri': 'spotify:track:7rO0JMFQtmsyZxlqH5g9ET',
#      'track_href': 'https://api.spotify.com/v1/tracks/7rO0JMFQtmsyZxlqH5g9ET',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rO0JMFQtmsyZxlqH5g9ET',
#      'duration_ms': 182507,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3yzlIX6xDX7DO9JAB4BFVY',
#    'track_name': 'Affamé #6 - Vital',
#    'track_uri_spotify': 'spotify:track:3yzlIX6xDX7DO9JAB4BFVY',
#    'track_audio_features_spotify': [{'danceability': 0.543,
#      'energy': 0.566,
#      'key': 1,
#      'loudness': -11.321,
#      'mode': 0,
#      'speechiness': 0.289,
#      'acousticness': 0.459,
#      'instrumentalness': 0,
#      'liveness': 0.103,
#      'valence': 0.499,
#      'tempo': 120.023,
#      'type': 'audio_features',
#      'id': '3yzlIX6xDX7DO9JAB4BFVY',
#      'uri': 'spotify:track:3yzlIX6xDX7DO9JAB4BFVY',
#      'track_href': 'https://api.spotify.com/v1/tracks/3yzlIX6xDX7DO9JAB4BFVY',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yzlIX6xDX7DO9JAB4BFVY',
#      'duration_ms': 200000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3MlOgwZ663O9LUHLP5ElxJ',
#    'track_name': 'Affamé #7 - Histoires de la vraie vie',
#    'track_uri_spotify': 'spotify:track:3MlOgwZ663O9LUHLP5ElxJ',
#    'track_audio_features_spotify': [{'danceability': 0.846,
#      'energy': 0.501,
#      'key': 5,
#      'loudness': -11.588,
#      'mode': 1,
#      'speechiness': 0.404,
#      'acousticness': 0.232,
#      'instrumentalness': 0,
#      'liveness': 0.181,
#      'valence': 0.455,
#      'tempo': 134.891,
#      'type': 'audio_features',
#      'id': '3MlOgwZ663O9LUHLP5ElxJ',
#      'uri': 'spotify:track:3MlOgwZ663O9LUHLP5ElxJ',
#      'track_href': 'https://api.spotify.com/v1/tracks/3MlOgwZ663O9LUHLP5ElxJ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MlOgwZ663O9LUHLP5ElxJ',
#      'duration_ms': 145778,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2puxOJQk78PKnWa0fcr3iz',
#    'track_name': 'Affamé #8 - Hayati',
#    'track_uri_spotify': 'spotify:track:2puxOJQk78PKnWa0fcr3iz',
#    'track_audio_features_spotify': [{'danceability': 0.735,
#      'energy': 0.537,
#      'key': 8,
#      'loudness': -10.153,
#      'mode': 0,
#      'speechiness': 0.184,
#      'acousticness': 0.228,
#      'instrumentalness': 0,
#      'liveness': 0.247,
#      'valence': 0.737,
#      'tempo': 144.748,
#      'type': 'audio_features',
#      'id': '2puxOJQk78PKnWa0fcr3iz',
#      'uri': 'spotify:track:2puxOJQk78PKnWa0fcr3iz',
#      'track_href': 'https://api.spotify.com/v1/tracks/2puxOJQk78PKnWa0fcr3iz',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2puxOJQk78PKnWa0fcr3iz',
#      'duration_ms': 158897,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6wKAxdtJ421Q4reiSIU2sb',
#    'track_name': 'Affamé #9 - GRRR',
#    'track_uri_spotify': 'spotify:track:6wKAxdtJ421Q4reiSIU2sb',
#    'track_audio_features_spotify': [{'danceability': 0.751,
#      'energy': 0.477,
#      'key': 7,
#      'loudness': -13.192,
#      'mode': 1,
#      'speechiness': 0.348,
#      'acousticness': 0.296,
#      'instrumentalness': 0,
#      'liveness': 0.13,
#      'valence': 0.484,
#      'tempo': 147.915,
#      'type': 'audio_features',
#      'id': '6wKAxdtJ421Q4reiSIU2sb',
#      'uri': 'spotify:track:6wKAxdtJ421Q4reiSIU2sb',
#      'track_href': 'https://api.spotify.com/v1/tracks/6wKAxdtJ421Q4reiSIU2sb',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wKAxdtJ421Q4reiSIU2sb',
#      'duration_ms': 155676,
#      'time_signature': 4}]},
#   {'track_id_spotify': '393EKVlfiWs7y3ae8D1CGw',
#    'track_name': 'Affamé #10 - Athéna',
#    'track_uri_spotify': 'spotify:track:393EKVlfiWs7y3ae8D1CGw',
#    'track_audio_features_spotify': [{'danceability': 0.539,
#      'energy': 0.418,
#      'key': 1,
#      'loudness': -13.1,
#      'mode': 1,
#      'speechiness': 0.236,
#      'acousticness': 0.637,
#      'instrumentalness': 6.68e-05,
#      'liveness': 0.117,
#      'valence': 0.325,
#      'tempo': 144.036,
#      'type': 'audio_features',
#      'id': '393EKVlfiWs7y3ae8D1CGw',
#      'uri': 'spotify:track:393EKVlfiWs7y3ae8D1CGw',
#      'track_href': 'https://api.spotify.com/v1/tracks/393EKVlfiWs7y3ae8D1CGw',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/393EKVlfiWs7y3ae8D1CGw',
#      'duration_ms': 230000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4z5zAsslMZkM6k6wOwzp0e',
#    'track_name': 'Affamé #11 – Photogénique (Boosk’Affamé)',
#    'track_uri_spotify': 'spotify:track:4z5zAsslMZkM6k6wOwzp0e',
#    'track_audio_features_spotify': [{'danceability': 0.599,
#      'energy': 0.603,
#      'key': 1,
#      'loudness': -8.131,
#      'mode': 1,
#      'speechiness': 0.193,
#      'acousticness': 0.0504,
#      'instrumentalness': 0,
#      'liveness': 0.116,
#      'valence': 0.359,
#      'tempo': 139.864,
#      'type': 'audio_features',
#      'id': '4z5zAsslMZkM6k6wOwzp0e',
#      'uri': 'spotify:track:4z5zAsslMZkM6k6wOwzp0e',
#      'track_href': 'https://api.spotify.com/v1/tracks/4z5zAsslMZkM6k6wOwzp0e',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4z5zAsslMZkM6k6wOwzp0e',
#      'duration_ms': 134000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4MVZjk9D5nfoJCKWvOVpAK',
#    'track_name': 'Affamé #12 - Sentimental',
#    'track_uri_spotify': 'spotify:track:4MVZjk9D5nfoJCKWvOVpAK',
#    'track_audio_features_spotify': [{'danceability': 0.688,
#      'energy': 0.435,
#      'key': 10,
#      'loudness': -11.376,
#      'mode': 0,
#      'speechiness': 0.0482,
#      'acousticness': 0.35,
#      'instrumentalness': 0,
#      'liveness': 0.0895,
#      'valence': 0.347,
#      'tempo': 139.978,
#      'type': 'audio_features',
#      'id': '4MVZjk9D5nfoJCKWvOVpAK',
#      'uri': 'spotify:track:4MVZjk9D5nfoJCKWvOVpAK',
#      'track_href': 'https://api.spotify.com/v1/tracks/4MVZjk9D5nfoJCKWvOVpAK',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MVZjk9D5nfoJCKWvOVpAK',
#      'duration_ms': 161143,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0GKcvPcN3CrFSiGmFquLDF',
#    'track_name': 'Affamé #13 - Marseille',
#    'track_uri_spotify': 'spotify:track:0GKcvPcN3CrFSiGmFquLDF',
#    'track_audio_features_spotify': [{'danceability': 0.404,
#      'energy': 0.372,
#      'key': 2,
#      'loudness': -13.869,
#      'mode': 0,
#      'speechiness': 0.0661,
#      'acousticness': 0.79,
#      'instrumentalness': 0,
#      'liveness': 0.189,
#      'valence': 0.273,
#      'tempo': 131.126,
#      'type': 'audio_features',
#      'id': '0GKcvPcN3CrFSiGmFquLDF',
#      'uri': 'spotify:track:0GKcvPcN3CrFSiGmFquLDF',
#      'track_href': 'https://api.spotify.com/v1/tracks/0GKcvPcN3CrFSiGmFquLDF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0GKcvPcN3CrFSiGmFquLDF',
#      'duration_ms': 208855,
#      'time_signature': 4}]},
#   {'track_id_spotify': '7tswq08eKBEDV2M78FoZY6',
#    'track_name': 'Médusa',
#    'track_uri_spotify': 'spotify:track:7tswq08eKBEDV2M78FoZY6',
#    'track_audio_features_spotify': [{'danceability': 0.798,
#      'energy': 0.582,
#      'key': 1,
#      'loudness': -7.872,
#      'mode': 0,
#      'speechiness': 0.0409,
#      'acousticness': 0.59,
#      'instrumentalness': 0,
#      'liveness': 0.166,
#      'valence': 0.758,
#      'tempo': 130.015,
#      'type': 'audio_features',
#      'id': '7tswq08eKBEDV2M78FoZY6',
#      'uri': 'spotify:track:7tswq08eKBEDV2M78FoZY6',
#      'track_href': 'https://api.spotify.com/v1/tracks/7tswq08eKBEDV2M78FoZY6',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tswq08eKBEDV2M78FoZY6',
#      'duration_ms': 195762,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2LQhGPCq3JA8kQQBf6i4Gy',
#    'track_name': 'Ça y est, ça y est',
#    'track_uri_spotify': 'spotify:track:2LQhGPCq3JA8kQQBf6i4Gy',
#    'track_audio_features_spotify': [{'danceability': 0.738,
#      'energy': 0.658,
#      'key': 0,
#      'loudness': -9.379,
#      'mode': 1,
#      'speechiness': 0.0588,
#      'acousticness': 0.408,
#      'instrumentalness': 0.000532,
#      'liveness': 0.104,
#      'valence': 0.54,
#      'tempo': 140.009,
#      'type': 'audio_features',
#      'id': '2LQhGPCq3JA8kQQBf6i4Gy',
#      'uri': 'spotify:track:2LQhGPCq3JA8kQQBf6i4Gy',
#      'track_href': 'https://api.spotify.com/v1/tracks/2LQhGPCq3JA8kQQBf6i4Gy',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LQhGPCq3JA8kQQBf6i4Gy',
#      'duration_ms': 161176,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3ekYBz94H1KjuiWZvllgia',
#    'track_name': 'Salopard',
#    'track_uri_spotify': 'spotify:track:3ekYBz94H1KjuiWZvllgia',
#    'track_audio_features_spotify': [{'danceability': 0.848,
#      'energy': 0.59,
#      'key': 0,
#      'loudness': -9.135,
#      'mode': 1,
#      'speechiness': 0.378,
#      'acousticness': 0.334,
#      'instrumentalness': 0,
#      'liveness': 0.107,
#      'valence': 0.43,
#      'tempo': 143.041,
#      'type': 'audio_features',
#      'id': '3ekYBz94H1KjuiWZvllgia',
#      'uri': 'spotify:track:3ekYBz94H1KjuiWZvllgia',
#      'track_href': 'https://api.spotify.com/v1/tracks/3ekYBz94H1KjuiWZvllgia',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ekYBz94H1KjuiWZvllgia',
#      'duration_ms': 145005,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2ULZZBTkBpnumtRBvarNUI',
#    'track_name': 'Cage dorée',
#    'track_uri_spotify': 'spotify:track:2ULZZBTkBpnumtRBvarNUI',
#    'track_audio_features_spotify': [{'danceability': 0.821,
#      'energy': 0.478,
#      'key': 5,
#      'loudness': -8.743,
#      'mode': 0,
#      'speechiness': 0.212,
#      'acousticness': 0.549,
#      'instrumentalness': 0,
#      'liveness': 0.0984,
#      'valence': 0.635,
#      'tempo': 77.569,
#      'type': 'audio_features',
#      'id': '2ULZZBTkBpnumtRBvarNUI',
#      'uri': 'spotify:track:2ULZZBTkBpnumtRBvarNUI',
#      'track_href': 'https://api.spotify.com/v1/tracks/2ULZZBTkBpnumtRBvarNUI',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ULZZBTkBpnumtRBvarNUI',
#      'duration_ms': 167226,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0C3sfFpIcBiaPzZDhZTyMY',
#    'track_name': 'Favélas',
#    'track_uri_spotify': 'spotify:track:0C3sfFpIcBiaPzZDhZTyMY',
#    'track_audio_features_spotify': [{'danceability': 0.886,
#      'energy': 0.645,
#      'key': 5,
#      'loudness': -7.773,
#      'mode': 0,
#      'speechiness': 0.234,
#      'acousticness': 0.118,
#      'instrumentalness': 0,
#      'liveness': 0.101,
#      'valence': 0.56,
#      'tempo': 135.016,
#      'type': 'audio_features',
#      'id': '0C3sfFpIcBiaPzZDhZTyMY',
#      'uri': 'spotify:track:0C3sfFpIcBiaPzZDhZTyMY',
#      'track_href': 'https://api.spotify.com/v1/tracks/0C3sfFpIcBiaPzZDhZTyMY',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0C3sfFpIcBiaPzZDhZTyMY',
#      'duration_ms': 199111,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6v4h1iRFwpnugtcjNbuqyC',
#    'track_name': 'NTM',
#    'track_uri_spotify': 'spotify:track:6v4h1iRFwpnugtcjNbuqyC',
#    'track_audio_features_spotify': [{'danceability': 0.774,
#      'energy': 0.586,
#      'key': 4,
#      'loudness': -10.535,
#      'mode': 0,
#      'speechiness': 0.13,
#      'acousticness': 0.0613,
#      'instrumentalness': 0,
#      'liveness': 0.12,
#      'valence': 0.31,
#      'tempo': 129.975,
#      'type': 'audio_features',
#      'id': '6v4h1iRFwpnugtcjNbuqyC',
#      'uri': 'spotify:track:6v4h1iRFwpnugtcjNbuqyC',
#      'track_href': 'https://api.spotify.com/v1/tracks/6v4h1iRFwpnugtcjNbuqyC',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6v4h1iRFwpnugtcjNbuqyC',
#      'duration_ms': 162857,
#      'time_signature': 4}]},
#   {'track_id_spotify': '18KmBPGqyM4Js4Y0POzEMQ',
#    'track_name': 'Zéro',
#    'track_uri_spotify': 'spotify:track:18KmBPGqyM4Js4Y0POzEMQ',
#    'track_audio_features_spotify': [{'danceability': 0.813,
#      'energy': 0.475,
#      'key': 9,
#      'loudness': -10.451,
#      'mode': 1,
#      'speechiness': 0.313,
#      'acousticness': 0.393,
#      'instrumentalness': 0,
#      'liveness': 0.0875,
#      'valence': 0.392,
#      'tempo': 144.961,
#      'type': 'audio_features',
#      'id': '18KmBPGqyM4Js4Y0POzEMQ',
#      'uri': 'spotify:track:18KmBPGqyM4Js4Y0POzEMQ',
#      'track_href': 'https://api.spotify.com/v1/tracks/18KmBPGqyM4Js4Y0POzEMQ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18KmBPGqyM4Js4Y0POzEMQ',
#      'duration_ms': 176571,
#      'time_signature': 4}]},
#   {'track_id_spotify': '44thwGAenKxQqMFSSCZHaa',
#    'track_name': 'Classe S',
#    'track_uri_spotify': 'spotify:track:44thwGAenKxQqMFSSCZHaa',
#    'track_audio_features_spotify': [{'danceability': 0.773,
#      'energy': 0.403,
#      'key': 4,
#      'loudness': -13.147,
#      'mode': 0,
#      'speechiness': 0.392,
#      'acousticness': 0.28,
#      'instrumentalness': 0,
#      'liveness': 0.101,
#      'valence': 0.216,
#      'tempo': 138.948,
#      'type': 'audio_features',
#      'id': '44thwGAenKxQqMFSSCZHaa',
#      'uri': 'spotify:track:44thwGAenKxQqMFSSCZHaa',
#      'track_href': 'https://api.spotify.com/v1/tracks/44thwGAenKxQqMFSSCZHaa',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44thwGAenKxQqMFSSCZHaa',
#      'duration_ms': 181929,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4KEUwlBzAzmyH9zBUfwgej',
#    'track_name': 'Padmé',
#    'track_uri_spotify': 'spotify:track:4KEUwlBzAzmyH9zBUfwgej',
#    'track_audio_features_spotify': [{'danceability': 0.823,
#      'energy': 0.394,
#      'key': 10,
#      'loudness': -13.455,
#      'mode': 0,
#      'speechiness': 0.152,
#      'acousticness': 0.309,
#      'instrumentalness': 0,
#      'liveness': 0.103,
#      'valence': 0.23,
#      'tempo': 132.885,
#      'type': 'audio_features',
#      'id': '4KEUwlBzAzmyH9zBUfwgej',
#      'uri': 'spotify:track:4KEUwlBzAzmyH9zBUfwgej',
#      'track_href': 'https://api.spotify.com/v1/tracks/4KEUwlBzAzmyH9zBUfwgej',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KEUwlBzAzmyH9zBUfwgej',
#      'duration_ms': 173357,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2PMFyuZ9h1ImlRTuIHE6ie',
#    'track_name': 'Paradis',
#    'track_uri_spotify': 'spotify:track:2PMFyuZ9h1ImlRTuIHE6ie',
#    'track_audio_features_spotify': [{'danceability': 0.745,
#      'energy': 0.504,
#      'key': 4,
#      'loudness': -11.811,
#      'mode': 0,
#      'speechiness': 0.0812,
#      'acousticness': 0.117,
#      'instrumentalness': 0,
#      'liveness': 0.224,
#      'valence': 0.251,
#      'tempo': 125.017,
#      'type': 'audio_features',
#      'id': '2PMFyuZ9h1ImlRTuIHE6ie',
#      'uri': 'spotify:track:2PMFyuZ9h1ImlRTuIHE6ie',
#      'track_href': 'https://api.spotify.com/v1/tracks/2PMFyuZ9h1ImlRTuIHE6ie',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PMFyuZ9h1ImlRTuIHE6ie',
#      'duration_ms': 153643,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5MBuVCqy6cNj7mZvOfYsbr',
#    'track_name': 'Bulle',
#    'track_uri_spotify': 'spotify:track:5MBuVCqy6cNj7mZvOfYsbr',
#    'track_audio_features_spotify': [{'danceability': 0.783,
#      'energy': 0.643,
#      'key': 5,
#      'loudness': -5.477,
#      'mode': 0,
#      'speechiness': 0.239,
#      'acousticness': 0.731,
#      'instrumentalness': 0,
#      'liveness': 0.0974,
#      'valence': 0.642,
#      'tempo': 134.989,
#      'type': 'audio_features',
#      'id': '5MBuVCqy6cNj7mZvOfYsbr',
#      'uri': 'spotify:track:5MBuVCqy6cNj7mZvOfYsbr',
#      'track_href': 'https://api.spotify.com/v1/tracks/5MBuVCqy6cNj7mZvOfYsbr',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MBuVCqy6cNj7mZvOfYsbr',
#      'duration_ms': 190222,
#      'time_signature': 4}]},
#   {'track_id_spotify': '6cjSsnYGEGqFCdHv2nYbel',
#    'track_name': 'Recommence',
#    'track_uri_spotify': 'spotify:track:6cjSsnYGEGqFCdHv2nYbel',
#    'track_audio_features_spotify': [{'danceability': 0.79,
#      'energy': 0.774,
#      'key': 3,
#      'loudness': -4.772,
#      'mode': 1,
#      'speechiness': 0.0565,
#      'acousticness': 0.403,
#      'instrumentalness': 2.87e-06,
#      'liveness': 0.0998,
#      'valence': 0.63,
#      'tempo': 104.096,
#      'type': 'audio_features',
#      'id': '6cjSsnYGEGqFCdHv2nYbel',
#      'uri': 'spotify:track:6cjSsnYGEGqFCdHv2nYbel',
#      'track_href': 'https://api.spotify.com/v1/tracks/6cjSsnYGEGqFCdHv2nYbel',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6cjSsnYGEGqFCdHv2nYbel',
#      'duration_ms': 170769,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2wxiIetwUQWHGzBfd7ZPM5',
#    'track_name': 'Dans le noir',
#    'track_uri_spotify': 'spotify:track:2wxiIetwUQWHGzBfd7ZPM5',
#    'track_audio_features_spotify': [{'danceability': 0.808,
#      'energy': 0.574,
#      'key': 11,
#      'loudness': -12.266,
#      'mode': 0,
#      'speechiness': 0.0725,
#      'acousticness': 0.716,
#      'instrumentalness': 0.00137,
#      'liveness': 0.122,
#      'valence': 0.697,
#      'tempo': 113.987,
#      'type': 'audio_features',
#      'id': '2wxiIetwUQWHGzBfd7ZPM5',
#      'uri': 'spotify:track:2wxiIetwUQWHGzBfd7ZPM5',
#      'track_href': 'https://api.spotify.com/v1/tracks/2wxiIetwUQWHGzBfd7ZPM5',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wxiIetwUQWHGzBfd7ZPM5',
#      'duration_ms': 191579,
#      'time_signature': 4}]},
#   {'track_id_spotify': '2Mq0ulRei2fjfNE9jarmIV',
#    'track_name': 'Mémoire',
#    'track_uri_spotify': 'spotify:track:2Mq0ulRei2fjfNE9jarmIV',
#    'track_audio_features_spotify': [{'danceability': 0.504,
#      'energy': 0.479,
#      'key': 4,
#      'loudness': -7.135,
#      'mode': 0,
#      'speechiness': 0.203,
#      'acousticness': 0.707,
#      'instrumentalness': 3.75e-05,
#      'liveness': 0.137,
#      'valence': 0.69,
#      'tempo': 118.762,
#      'type': 'audio_features',
#      'id': '2Mq0ulRei2fjfNE9jarmIV',
#      'uri': 'spotify:track:2Mq0ulRei2fjfNE9jarmIV',
#      'track_href': 'https://api.spotify.com/v1/tracks/2Mq0ulRei2fjfNE9jarmIV',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Mq0ulRei2fjfNE9jarmIV',
#      'duration_ms': 228000,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3QsiZMu6gbDtdX3W8rbd7j',
#    'track_name': 'Pour mourir',
#    'track_uri_spotify': 'spotify:track:3QsiZMu6gbDtdX3W8rbd7j',
#    'track_audio_features_spotify': [{'danceability': 0.801,
#      'energy': 0.614,
#      'key': 0,
# ...
#      'uri': 'spotify:track:520hFayW1Is2Z7JjKXEzcF',
#      'track_href': 'https://api.spotify.com/v1/tracks/520hFayW1Is2Z7JjKXEzcF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/520hFayW1Is2Z7JjKXEzcF',
#      'duration_ms': 176571,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4qyKWMcClOWF59wVTNYmZN',
#    'track_name': 'Classe S',
#    'track_uri_spotify': 'spotify:track:4qyKWMcClOWF59wVTNYmZN',
#    'track_audio_features_spotify': [{'danceability': 0.773,
#      'energy': 0.403,
#      'key': 4,
#      'loudness': -13.147,
#      'mode': 0,
#      'speechiness': 0.392,
#      'acousticness': 0.28,
#      'instrumentalness': 0,
#      'liveness': 0.101,
#      'valence': 0.216,
#      'tempo': 138.948,
#      'type': 'audio_features',
#      'id': '4qyKWMcClOWF59wVTNYmZN',
#      'uri': 'spotify:track:4qyKWMcClOWF59wVTNYmZN',
#      'track_href': 'https://api.spotify.com/v1/tracks/4qyKWMcClOWF59wVTNYmZN',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qyKWMcClOWF59wVTNYmZN',
#      'duration_ms': 181929,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3LbOks6Z4VoeOtqa1VMR2D',
#    'track_name': 'Padmé',
#    'track_uri_spotify': 'spotify:track:3LbOks6Z4VoeOtqa1VMR2D',
#    'track_audio_features_spotify': [{'danceability': 0.823,
#      'energy': 0.394,
#      'key': 10,
#      'loudness': -13.455,
#      'mode': 0,
#      'speechiness': 0.152,
#      'acousticness': 0.309,
#      'instrumentalness': 0,
#      'liveness': 0.103,
#      'valence': 0.23,
#      'tempo': 132.885,
#      'type': 'audio_features',
#      'id': '3LbOks6Z4VoeOtqa1VMR2D',
#      'uri': 'spotify:track:3LbOks6Z4VoeOtqa1VMR2D',
#      'track_href': 'https://api.spotify.com/v1/tracks/3LbOks6Z4VoeOtqa1VMR2D',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LbOks6Z4VoeOtqa1VMR2D',
#      'duration_ms': 173357,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5RgsC94QflBPFzv0YAwCpJ',
#    'track_name': 'Paradis',
#    'track_uri_spotify': 'spotify:track:5RgsC94QflBPFzv0YAwCpJ',
#    'track_audio_features_spotify': [{'danceability': 0.745,
#      'energy': 0.504,
#      'key': 4,
#      'loudness': -11.811,
#      'mode': 0,
#      'speechiness': 0.0812,
#      'acousticness': 0.117,
#      'instrumentalness': 0,
#      'liveness': 0.224,
#      'valence': 0.251,
#      'tempo': 125.017,
#      'type': 'audio_features',
#      'id': '5RgsC94QflBPFzv0YAwCpJ',
#      'uri': 'spotify:track:5RgsC94QflBPFzv0YAwCpJ',
#      'track_href': 'https://api.spotify.com/v1/tracks/5RgsC94QflBPFzv0YAwCpJ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RgsC94QflBPFzv0YAwCpJ',
#      'duration_ms': 153643,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5odNOu8oYceoa8tfRJTxZo',
#    'track_name': 'Potentiel (OM SESSIONS)',
#    'track_uri_spotify': 'spotify:track:5odNOu8oYceoa8tfRJTxZo',
#    'track_audio_features_spotify': [{'danceability': 0.784,
#      'energy': 0.418,
#      'key': 7,
#      'loudness': -10.823,
#      'mode': 1,
#      'speechiness': 0.0729,
#      'acousticness': 0.76,
#      'instrumentalness': 1.52e-06,
#      'liveness': 0.109,
#      'valence': 0.333,
#      'tempo': 108.07,
#      'type': 'audio_features',
#      'id': '5odNOu8oYceoa8tfRJTxZo',
#      'uri': 'spotify:track:5odNOu8oYceoa8tfRJTxZo',
#      'track_href': 'https://api.spotify.com/v1/tracks/5odNOu8oYceoa8tfRJTxZo',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5odNOu8oYceoa8tfRJTxZo',
#      'duration_ms': 147789,
#      'time_signature': 4}]},
#   {'track_id_spotify': '7CPCNbPNPaIalNCfDdYvqm',
#    'track_name': 'Low',
#    'track_uri_spotify': 'spotify:track:7CPCNbPNPaIalNCfDdYvqm',
#    'track_audio_features_spotify': [{'danceability': 0.789,
#      'energy': 0.684,
#      'key': 3,
#      'loudness': -7.705,
#      'mode': 0,
#      'speechiness': 0.276,
#      'acousticness': 0.528,
#      'instrumentalness': 1.21e-06,
#      'liveness': 0.108,
#      'valence': 0.371,
#      'tempo': 142.015,
#      'type': 'audio_features',
#      'id': '7CPCNbPNPaIalNCfDdYvqm',
#      'uri': 'spotify:track:7CPCNbPNPaIalNCfDdYvqm',
#      'track_href': 'https://api.spotify.com/v1/tracks/7CPCNbPNPaIalNCfDdYvqm',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CPCNbPNPaIalNCfDdYvqm',
#      'duration_ms': 182535,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5UdqpEvworqu5ca6FOaOKE',
#    'track_name': 'Demain',
#    'track_uri_spotify': 'spotify:track:5UdqpEvworqu5ca6FOaOKE',
#    'track_audio_features_spotify': [{'danceability': 0.795,
#      'energy': 0.618,
#      'key': 7,
#      'loudness': -6.188,
#      'mode': 0,
#      'speechiness': 0.0814,
#      'acousticness': 0.75,
#      'instrumentalness': 0,
#      'liveness': 0.104,
#      'valence': 0.624,
#      'tempo': 130.053,
#      'type': 'audio_features',
#      'id': '5UdqpEvworqu5ca6FOaOKE',
#      'uri': 'spotify:track:5UdqpEvworqu5ca6FOaOKE',
#      'track_href': 'https://api.spotify.com/v1/tracks/5UdqpEvworqu5ca6FOaOKE',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UdqpEvworqu5ca6FOaOKE',
#      'duration_ms': 183821,
#      'time_signature': 4}]},
#   {'track_id_spotify': '1XuKsOmxB6GihrJPvefxOQ',
#    'track_name': 'Recommence',
#    'track_uri_spotify': 'spotify:track:1XuKsOmxB6GihrJPvefxOQ',
#    'track_audio_features_spotify': [{'danceability': 0.79,
#      'energy': 0.774,
#      'key': 3,
#      'loudness': -4.772,
#      'mode': 1,
#      'speechiness': 0.0565,
#      'acousticness': 0.403,
#      'instrumentalness': 2.87e-06,
#      'liveness': 0.0998,
#      'valence': 0.63,
#      'tempo': 104.096,
#      'type': 'audio_features',
#      'id': '1XuKsOmxB6GihrJPvefxOQ',
#      'uri': 'spotify:track:1XuKsOmxB6GihrJPvefxOQ',
#      'track_href': 'https://api.spotify.com/v1/tracks/1XuKsOmxB6GihrJPvefxOQ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XuKsOmxB6GihrJPvefxOQ',
#      'duration_ms': 170769,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5pknhIxHotSbbUB5KFQwBb',
#    'track_name': 'Affamé #1 - Shook',
#    'track_uri_spotify': 'spotify:track:5pknhIxHotSbbUB5KFQwBb',
#    'track_audio_features_spotify': [{'danceability': 0.795,
#      'energy': 0.638,
#      'key': 6,
#      'loudness': -8.273,
#      'mode': 1,
#      'speechiness': 0.145,
#      'acousticness': 0.34,
#      'instrumentalness': 0,
#      'liveness': 0.134,
#      'valence': 0.627,
#      'tempo': 147.027,
#      'type': 'audio_features',
#      'id': '5pknhIxHotSbbUB5KFQwBb',
#      'uri': 'spotify:track:5pknhIxHotSbbUB5KFQwBb',
#      'track_href': 'https://api.spotify.com/v1/tracks/5pknhIxHotSbbUB5KFQwBb',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pknhIxHotSbbUB5KFQwBb',
#      'duration_ms': 191020,
#      'time_signature': 4}]},
#   {'track_id_spotify': '3iiNSSBF45PRf8uS7SeAZF',
#    'track_name': 'Affamé #2 - 21',
#    'track_uri_spotify': 'spotify:track:3iiNSSBF45PRf8uS7SeAZF',
#    'track_audio_features_spotify': [{'danceability': 0.825,
#      'energy': 0.637,
#      'key': 9,
#      'loudness': -7.223,
#      'mode': 1,
#      'speechiness': 0.325,
#      'acousticness': 0.378,
#      'instrumentalness': 0,
#      'liveness': 0.151,
#      'valence': 0.492,
#      'tempo': 139.826,
#      'type': 'audio_features',
#      'id': '3iiNSSBF45PRf8uS7SeAZF',
#      'uri': 'spotify:track:3iiNSSBF45PRf8uS7SeAZF',
#      'track_href': 'https://api.spotify.com/v1/tracks/3iiNSSBF45PRf8uS7SeAZF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iiNSSBF45PRf8uS7SeAZF',
#      'duration_ms': 181714,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5C9K2fgyAdBVhZ5BB0Osi4',
#    'track_name': 'Affamé #3 - No Party',
#    'track_uri_spotify': 'spotify:track:5C9K2fgyAdBVhZ5BB0Osi4',
#    'track_audio_features_spotify': [{'danceability': 0.844,
#      'energy': 0.574,
#      'key': 1,
#      'loudness': -8.457,
#      'mode': 1,
#      'speechiness': 0.441,
#      'acousticness': 0.0991,
#      'instrumentalness': 0,
#      'liveness': 0.138,
#      'valence': 0.55,
#      'tempo': 133.719,
#      'type': 'audio_features',
#      'id': '5C9K2fgyAdBVhZ5BB0Osi4',
#      'uri': 'spotify:track:5C9K2fgyAdBVhZ5BB0Osi4',
#      'track_href': 'https://api.spotify.com/v1/tracks/5C9K2fgyAdBVhZ5BB0Osi4',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5C9K2fgyAdBVhZ5BB0Osi4',
#      'duration_ms': 157612,
#      'time_signature': 4}]},
#   {'track_id_spotify': '7HAWNg9Opc2hdPCpx0S1kV',
#    'track_name': 'Affamé #4 - Survivant',
#    'track_uri_spotify': 'spotify:track:7HAWNg9Opc2hdPCpx0S1kV',
#    'track_audio_features_spotify': [{'danceability': 0.847,
#      'energy': 0.646,
#      'key': 4,
#      'loudness': -6.734,
#      'mode': 0,
#      'speechiness': 0.264,
#      'acousticness': 0.319,
#      'instrumentalness': 0,
#      'liveness': 0.101,
#      'valence': 0.573,
#      'tempo': 139.924,
#      'type': 'audio_features',
#      'id': '7HAWNg9Opc2hdPCpx0S1kV',
#      'uri': 'spotify:track:7HAWNg9Opc2hdPCpx0S1kV',
#      'track_href': 'https://api.spotify.com/v1/tracks/7HAWNg9Opc2hdPCpx0S1kV',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HAWNg9Opc2hdPCpx0S1kV',
#      'duration_ms': 197143,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0jJgm777s4RnQiLhFSMQ5h',
#    'track_name': 'Affamé #5 - Seul',
#    'track_uri_spotify': 'spotify:track:0jJgm777s4RnQiLhFSMQ5h',
#    'track_audio_features_spotify': [{'danceability': 0.789,
#      'energy': 0.688,
#      'key': 0,
#      'loudness': -7.718,
#      'mode': 0,
#      'speechiness': 0.204,
#      'acousticness': 0.176,
#      'instrumentalness': 0,
#      'liveness': 0.0749,
#      'valence': 0.477,
#      'tempo': 81.997,
#      'type': 'audio_features',
#      'id': '0jJgm777s4RnQiLhFSMQ5h',
#      'uri': 'spotify:track:0jJgm777s4RnQiLhFSMQ5h',
#      'track_href': 'https://api.spotify.com/v1/tracks/0jJgm777s4RnQiLhFSMQ5h',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jJgm777s4RnQiLhFSMQ5h',
#      'duration_ms': 191707,
#      'time_signature': 4}]},
#   {'track_id_spotify': '37u6IWigi7R36grAG2vwS3',
#    'track_name': "Quand j'fume",
#    'track_uri_spotify': 'spotify:track:37u6IWigi7R36grAG2vwS3',
#    'track_audio_features_spotify': [{'danceability': 0.797,
#      'energy': 0.811,
#      'key': 0,
#      'loudness': -6.548,
#      'mode': 0,
#      'speechiness': 0.0778,
#      'acousticness': 0.809,
#      'instrumentalness': 1.79e-05,
#      'liveness': 0.163,
#      'valence': 0.723,
#      'tempo': 129.945,
#      'type': 'audio_features',
#      'id': '37u6IWigi7R36grAG2vwS3',
#      'uri': 'spotify:track:37u6IWigi7R36grAG2vwS3',
#      'track_href': 'https://api.spotify.com/v1/tracks/37u6IWigi7R36grAG2vwS3',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37u6IWigi7R36grAG2vwS3',
#      'duration_ms': 142154,
#      'time_signature': 4}]},
#   {'track_id_spotify': '4YJlTaFatD4ebguPxR6ZHv',
#    'track_name': 'Green',
#    'track_uri_spotify': 'spotify:track:4YJlTaFatD4ebguPxR6ZHv',
#    'track_audio_features_spotify': [{'danceability': 0.518,
#      'energy': 0.633,
#      'key': 1,
#      'loudness': -6.197,
#      'mode': 1,
#      'speechiness': 0.277,
#      'acousticness': 0.747,
#      'instrumentalness': 0,
#      'liveness': 0.14,
#      'valence': 0.462,
#      'tempo': 88.361,
#      'type': 'audio_features',
#      'id': '4YJlTaFatD4ebguPxR6ZHv',
#      'uri': 'spotify:track:4YJlTaFatD4ebguPxR6ZHv',
#      'track_href': 'https://api.spotify.com/v1/tracks/4YJlTaFatD4ebguPxR6ZHv',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YJlTaFatD4ebguPxR6ZHv',
#      'duration_ms': 150000,
#      'time_signature': 3}]},
#   {'track_id_spotify': '4ABLTQi9yWB5WC9iemUcOF',
#    'track_name': 'Disaster',
#    'track_uri_spotify': 'spotify:track:4ABLTQi9yWB5WC9iemUcOF',
#    'track_audio_features_spotify': [{'danceability': 0.641,
#      'energy': 0.468,
#      'key': 2,
#      'loudness': -8.408,
#      'mode': 1,
#      'speechiness': 0.369,
#      'acousticness': 0.759,
#      'instrumentalness': 1.15e-06,
#      'liveness': 0.109,
#      'valence': 0.486,
#      'tempo': 122.119,
#      'type': 'audio_features',
#      'id': '4ABLTQi9yWB5WC9iemUcOF',
#      'uri': 'spotify:track:4ABLTQi9yWB5WC9iemUcOF',
#      'track_href': 'https://api.spotify.com/v1/tracks/4ABLTQi9yWB5WC9iemUcOF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ABLTQi9yWB5WC9iemUcOF',
#      'duration_ms': 169278,
#      'time_signature': 4}]},
#   {'track_id_spotify': '66PVjOeCXheSXKlFNtLjRR',
#    'track_name': "Passe à l'appart",
#    'track_uri_spotify': 'spotify:track:66PVjOeCXheSXKlFNtLjRR',
#    'track_audio_features_spotify': [{'danceability': 0.867,
#      'energy': 0.508,
#      'key': 1,
#      'loudness': -10.498,
#      'mode': 1,
#      'speechiness': 0.459,
#      'acousticness': 0.52,
#      'instrumentalness': 2.96e-06,
#      'liveness': 0.148,
#      'valence': 0.404,
#      'tempo': 135.153,
#      'type': 'audio_features',
#      'id': '66PVjOeCXheSXKlFNtLjRR',
#      'uri': 'spotify:track:66PVjOeCXheSXKlFNtLjRR',
#      'track_href': 'https://api.spotify.com/v1/tracks/66PVjOeCXheSXKlFNtLjRR',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/66PVjOeCXheSXKlFNtLjRR',
#      'duration_ms': 184889,
#      'time_signature': 4}]},
#   {'track_id_spotify': '0z04vNP9kMa2ikRcue24gf',
#    'track_name': "Dans L'mal",
#    'track_uri_spotify': 'spotify:track:0z04vNP9kMa2ikRcue24gf',
#    'track_audio_features_spotify': [{'danceability': 0.85,
#      'energy': 0.569,
#      'key': 7,
#      'loudness': -9.594,
#      'mode': 1,
#      'speechiness': 0.417,
#      'acousticness': 0.376,
#      'instrumentalness': 4.34e-06,
#      'liveness': 0.0894,
#      'valence': 0.352,
#      'tempo': 134.945,
#      'type': 'audio_features',
#      'id': '0z04vNP9kMa2ikRcue24gf',
#      'uri': 'spotify:track:0z04vNP9kMa2ikRcue24gf',
#      'track_href': 'https://api.spotify.com/v1/tracks/0z04vNP9kMa2ikRcue24gf',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0z04vNP9kMa2ikRcue24gf',
#      'duration_ms': 220444,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5AERfJhWMvY6JFXsToXqIH',
#    'track_name': 'Tjpc',
#    'track_uri_spotify': 'spotify:track:5AERfJhWMvY6JFXsToXqIH',
#    'track_audio_features_spotify': [{'danceability': 0.783,
#      'energy': 0.524,
#      'key': 10,
#      'loudness': -6.492,
#      'mode': 1,
#      'speechiness': 0.0685,
#      'acousticness': 0.51,
#      'instrumentalness': 0,
#      'liveness': 0.111,
#      'valence': 0.191,
#      'tempo': 125.044,
#      'type': 'audio_features',
#      'id': '5AERfJhWMvY6JFXsToXqIH',
#      'uri': 'spotify:track:5AERfJhWMvY6JFXsToXqIH',
#      'track_href': 'https://api.spotify.com/v1/tracks/5AERfJhWMvY6JFXsToXqIH',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AERfJhWMvY6JFXsToXqIH',
#      'duration_ms': 200516,
#      'time_signature': 4}]},
#   {'track_id_spotify': '1Wi2mNxtNgkMuykhHudCPg',
#    'track_name': 'Règlement Freestyle #6',
#    'track_uri_spotify': 'spotify:track:1Wi2mNxtNgkMuykhHudCPg',
#    'track_audio_features_spotify': [{'danceability': 0.881,
#      'energy': 0.497,
#      'key': 10,
#      'loudness': -10.349,
#      'mode': 1,
#      'speechiness': 0.167,
#      'acousticness': 0.789,
#      'instrumentalness': 0,
#      'liveness': 0.11,
#      'valence': 0.505,
#      'tempo': 129.967,
#      'type': 'audio_features',
#      'id': '1Wi2mNxtNgkMuykhHudCPg',
#      'uri': 'spotify:track:1Wi2mNxtNgkMuykhHudCPg',
#      'track_href': 'https://api.spotify.com/v1/tracks/1Wi2mNxtNgkMuykhHudCPg',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Wi2mNxtNgkMuykhHudCPg',
#      'duration_ms': 171692,
#      'time_signature': 4}]},
#   {'track_id_spotify': '5cWKh0tzGKbiaNzh2IxTPW',
#    'track_name': 'Favaro',
#    'track_uri_spotify': 'spotify:track:5cWKh0tzGKbiaNzh2IxTPW',
#    'track_audio_features_spotify': [{'danceability': 0.748,
#      'energy': 0.594,
#      'key': 1,
#      'loudness': -7.931,
#      'mode': 1,
#      'speechiness': 0.0867,
#      'acousticness': 0.639,
#      'instrumentalness': 9e-05,
#      'liveness': 0.115,
#      'valence': 0.557,
#      'tempo': 131.962,
#      'type': 'audio_features',
#      'id': '5cWKh0tzGKbiaNzh2IxTPW',
#      'uri': 'spotify:track:5cWKh0tzGKbiaNzh2IxTPW',
#      'track_href': 'https://api.spotify.com/v1/tracks/5cWKh0tzGKbiaNzh2IxTPW',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cWKh0tzGKbiaNzh2IxTPW',
#      'duration_ms': 205455,
#      'time_signature': 4}]}]}

# %%
spotify_artist_profile_data = pd.DataFrame.from_dict(spotify_artist_info, orient="index").T

# %%
spotify_artist_profile_data
# Out:
#   artist_name       artist_id_spotify                     artist_uri_spotify  \
# 0     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8
#
#   artist_link_picture_spotify  \
# 0                     UNKNOWN
#
#                                artist_genres_spotify  \
# 0  [cloud rap francais, french hip hop, pop urbai...
#
#   artist_popularity_spotify  \
# 0                        60
#
#                       artist_related_artists_spotify  \
# 0  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
#
#                                        artist_tracks
# 0  [{'track_id_spotify': '0H8sSKJrB1xlmp5i0YgGrs'...

# %%
artist_spotify_information = spotify_artist_profile_data.drop(['artist_tracks'], inplace=False, axis = 1)
artist_spotify_songs = spotify_artist_profile_data[['artist_name', 'artist_id_spotify', 'artist_tracks']].explode('artist_tracks')

# %%
artist_spotify_information.reset_index(inplace=True, drop=True)

# %%
artist_spotify_information
# Out:
#   artist_name       artist_id_spotify                     artist_uri_spotify  \
# 0     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8
#
#   artist_link_picture_spotify  \
# 0                     UNKNOWN
#
#                                artist_genres_spotify  \
# 0  [cloud rap francais, french hip hop, pop urbai...
#
#   artist_popularity_spotify                     artist_related_artists_spotify
# 0                        60  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...

# %%
artist_spotify_songs.reset_index(inplace=True, drop = True)

# %%
artist_spotify_song_data = pd.DataFrame(list(artist_spotify_songs['artist_tracks']))

# %%
artist_spotify_song_data_audio_features = pd.DataFrame(list(artist_spotify_song_data['track_audio_features_spotify'].apply(lambda x : x[0] if x else {})))

# %%
artist_spotify_song_info = pd.concat([artist_spotify_song_data,artist_spotify_song_data_audio_features], axis=1).drop(['track_audio_features_spotify', 'type', 'id', 'uri', 'track_href', 'analysis_url'], inplace= False, axis = 1)

# %%
artist_spotify_song_info['artist_id_spotify'] =  artist_spotify_information['artist_id_spotify'].values[0]

# %%
artist_spotify_song_info
# Out:
#            track_id_spotify              track_name  \
# 0    0H8sSKJrB1xlmp5i0YgGrs               Mouchkila
# 1    1HaOYE4mMGG49HOf98uLTD              À ma guise
# 2    2lk8jLE8cF7NSL50pOXoTF         Le grand cirque
# 3    33GQLlkZsYNw569Pr0ZAXw                 Million
# 4    5lV989DHPY9NO7ygRAAG2r               Printemps
# ..                      ...                     ...
# 153  66PVjOeCXheSXKlFNtLjRR        Passe à l'appart
# 154  0z04vNP9kMa2ikRcue24gf              Dans L'mal
# 155  5AERfJhWMvY6JFXsToXqIH                    Tjpc
# 156  1Wi2mNxtNgkMuykhHudCPg  Règlement Freestyle #6
# 157  5cWKh0tzGKbiaNzh2IxTPW                  Favaro
#
#                         track_uri_spotify  danceability  energy  key  \
# 0    spotify:track:0H8sSKJrB1xlmp5i0YgGrs         0.600   0.499    5
# 1    spotify:track:1HaOYE4mMGG49HOf98uLTD         0.706   0.618    4
# 2    spotify:track:2lk8jLE8cF7NSL50pOXoTF         0.619   0.323    3
# 3    spotify:track:33GQLlkZsYNw569Pr0ZAXw         0.746   0.498    9
# 4    spotify:track:5lV989DHPY9NO7ygRAAG2r         0.687   0.696    1
# ..                                    ...           ...     ...  ...
# 153  spotify:track:66PVjOeCXheSXKlFNtLjRR         0.867   0.508    1
# 154  spotify:track:0z04vNP9kMa2ikRcue24gf         0.850   0.569    7
# 155  spotify:track:5AERfJhWMvY6JFXsToXqIH         0.783   0.524   10
# 156  spotify:track:1Wi2mNxtNgkMuykhHudCPg         0.881   0.497   10
# 157  spotify:track:5cWKh0tzGKbiaNzh2IxTPW         0.748   0.594    1
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -7.570     0       0.0364         0.673          0.000000    0.2690
# 1      -6.832     0       0.0828         0.634          0.000076    0.0907
# 2      -7.642     0       0.0379         0.464          0.000041    0.2060
# 3      -9.168     0       0.0632         0.796          0.000000    0.0946
# 4      -6.757     0       0.0649         0.261          0.000000    0.1050
# ..        ...   ...          ...           ...               ...       ...
# 153   -10.498     1       0.4590         0.520          0.000003    0.1480
# 154    -9.594     1       0.4170         0.376          0.000004    0.0894
# 155    -6.492     1       0.0685         0.510          0.000000    0.1110
# 156   -10.349     1       0.1670         0.789          0.000000    0.1100
# 157    -7.931     1       0.0867         0.639          0.000090    0.1150
#
#      valence    tempo  duration_ms  time_signature       artist_id_spotify
# 0      0.578  160.073       226413               4  5CtPAGoxpJ4yLJLx6CSrO8
# 1      0.349  137.988       161773               4  5CtPAGoxpJ4yLJLx6CSrO8
# 2      0.369  130.008       241760               5  5CtPAGoxpJ4yLJLx6CSrO8
# 3      0.777  131.975       211493               4  5CtPAGoxpJ4yLJLx6CSrO8
# 4      0.446  112.933       193373               4  5CtPAGoxpJ4yLJLx6CSrO8
# ..       ...      ...          ...             ...                     ...
# 153    0.404  135.153       184889               4  5CtPAGoxpJ4yLJLx6CSrO8
# 154    0.352  134.945       220444               4  5CtPAGoxpJ4yLJLx6CSrO8
# 155    0.191  125.044       200516               4  5CtPAGoxpJ4yLJLx6CSrO8
# 156    0.505  129.967       171692               4  5CtPAGoxpJ4yLJLx6CSrO8
# 157    0.557  131.962       205455               4  5CtPAGoxpJ4yLJLx6CSrO8
#
# [158 rows x 17 columns]

# %%
pd.merge(artist_spotify_information, artist_spotify_song_info)
# Out:
#     artist_name       artist_id_spotify  \
# 0       Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 1       Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 2       Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 3       Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 4       Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# ..          ...                     ...
# 153     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 154     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 155     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 156     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
# 157     Zamdane  5CtPAGoxpJ4yLJLx6CSrO8
#
#                         artist_uri_spotify artist_link_picture_spotify  \
# 0    spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 1    spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 2    spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 3    spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 4    spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# ..                                     ...                         ...
# 153  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 154  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 155  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 156  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
# 157  spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8                     UNKNOWN
#
#                                  artist_genres_spotify  \
# 0    [cloud rap francais, french hip hop, pop urbai...
# 1    [cloud rap francais, french hip hop, pop urbai...
# 2    [cloud rap francais, french hip hop, pop urbai...
# 3    [cloud rap francais, french hip hop, pop urbai...
# 4    [cloud rap francais, french hip hop, pop urbai...
# ..                                                 ...
# 153  [cloud rap francais, french hip hop, pop urbai...
# 154  [cloud rap francais, french hip hop, pop urbai...
# 155  [cloud rap francais, french hip hop, pop urbai...
# 156  [cloud rap francais, french hip hop, pop urbai...
# 157  [cloud rap francais, french hip hop, pop urbai...
#
#     artist_popularity_spotify  \
# 0                          60
# 1                          60
# 2                          60
# 3                          60
# 4                          60
# ..                        ...
# 153                        60
# 154                        60
# 155                        60
# 156                        60
# 157                        60
#
#                         artist_related_artists_spotify  \
# 0    [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 1    [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 2    [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 3    [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 4    [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# ..                                                 ...
# 153  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 154  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 155  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 156  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
# 157  [Lesram, HOUDI, So La Lune, Rounhaa, Dau, Rapl...
#
#            track_id_spotify              track_name  \
# 0    0H8sSKJrB1xlmp5i0YgGrs               Mouchkila
# 1    1HaOYE4mMGG49HOf98uLTD              À ma guise
# 2    2lk8jLE8cF7NSL50pOXoTF         Le grand cirque
# 3    33GQLlkZsYNw569Pr0ZAXw                 Million
# 4    5lV989DHPY9NO7ygRAAG2r               Printemps
# ..                      ...                     ...
# 153  66PVjOeCXheSXKlFNtLjRR        Passe à l'appart
# 154  0z04vNP9kMa2ikRcue24gf              Dans L'mal
# 155  5AERfJhWMvY6JFXsToXqIH                    Tjpc
# 156  1Wi2mNxtNgkMuykhHudCPg  Règlement Freestyle #6
# 157  5cWKh0tzGKbiaNzh2IxTPW                  Favaro
#
#                         track_uri_spotify  ...  loudness  mode  speechiness  \
# 0    spotify:track:0H8sSKJrB1xlmp5i0YgGrs  ...    -7.570     0       0.0364
# 1    spotify:track:1HaOYE4mMGG49HOf98uLTD  ...    -6.832     0       0.0828
# 2    spotify:track:2lk8jLE8cF7NSL50pOXoTF  ...    -7.642     0       0.0379
# 3    spotify:track:33GQLlkZsYNw569Pr0ZAXw  ...    -9.168     0       0.0632
# 4    spotify:track:5lV989DHPY9NO7ygRAAG2r  ...    -6.757     0       0.0649
# ..                                    ...  ...       ...   ...          ...
# 153  spotify:track:66PVjOeCXheSXKlFNtLjRR  ...   -10.498     1       0.4590
# 154  spotify:track:0z04vNP9kMa2ikRcue24gf  ...    -9.594     1       0.4170
# 155  spotify:track:5AERfJhWMvY6JFXsToXqIH  ...    -6.492     1       0.0685
# 156  spotify:track:1Wi2mNxtNgkMuykhHudCPg  ...   -10.349     1       0.1670
# 157  spotify:track:5cWKh0tzGKbiaNzh2IxTPW  ...    -7.931     1       0.0867
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0           0.673          0.000000    0.2690    0.578  160.073       226413
# 1           0.634          0.000076    0.0907    0.349  137.988       161773
# 2           0.464          0.000041    0.2060    0.369  130.008       241760
# 3           0.796          0.000000    0.0946    0.777  131.975       211493
# 4           0.261          0.000000    0.1050    0.446  112.933       193373
# ..            ...               ...       ...      ...      ...          ...
# 153         0.520          0.000003    0.1480    0.404  135.153       184889
# 154         0.376          0.000004    0.0894    0.352  134.945       220444
# 155         0.510          0.000000    0.1110    0.191  125.044       200516
# 156         0.789          0.000000    0.1100    0.505  129.967       171692
# 157         0.639          0.000090    0.1150    0.557  131.962       205455
#
#      time_signature
# 0                 4
# 1                 4
# 2                 5
# 3                 4
# 4                 4
# ..              ...
# 153               4
# 154               4
# 155               4
# 156               4
# 157               4
#
# [158 rows x 23 columns]
